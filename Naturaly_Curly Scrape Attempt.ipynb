# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
html_page = requests.get('https://curltalk.naturallycurly.com/discussion/187776/wavemaker-stringy-hair') #Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="r8espbQAjIbeGDwID6nId4gRNQr3p6uaawtkpKQI" name="csrf-token"/>
# <meta content="index, follow" name="robots"/>
# <meta content="244330805725130" name="fb:app_id" property="fb:app_id"/>
# <meta content="44517541327" name="fb:pages" property="fb:pages"/>
# <meta content="e889ec2da676423098e4ea8786e4178d" name="p:domain_verify" property="p:domain_verify"/>
# <title>Wavemaker - stringy hair — CurlTalk</title>
# <link href="/applications/dashboard/design/style.css?v=3.0.5d2f593f" media="all" rel="stylesheet"/>
# <link href="https://curltalk.naturallycurly.com/applications/dashboard/design/style-compat.css?v=3.1-2019.009.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/Signatures/design/signature.css?v=1.6.1.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/Reactions/design/reactions.css?v=1.4.6.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/Polls/design/polls.css?v=1.2.4.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/IndexPhotos/design/indexphotos.css?v=1.2.2.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/Warnings2/design/warnings.css?v=2.5.1.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/badges/design/badges.css?v=1.6.1.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/AdvancedSearch/design/advanced-search.css?v=1.1.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/resources/design/vanillicon.css?v=3.1-2019.009.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/editor/design/editor.css?v=1.8.1.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/applications/vanilla/design/tag.css?v=3.0.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/ShareThis/design/ShareThis.css?v=1.3.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/plugins/Online/design/online.css?v=1.7.1.5d2f593f" media="all" rel="stylesheet"/>
# <link href="/applications/vanilla/design/spoilers.css?v=3.0.5d2f593f" media="all" rel="stylesheet"/>
# <link href="https://us.v-cdn.net/6030387/uploads/favicon_742e5b705682632797ea27349bba3110.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://us.v-cdn.net/6030387/uploads/favicon-152-a80f4638f8f309f4db688f9db91b3197.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://curltalk.naturallycurly.com/discussion/187776/wavemaker-stringy-hair" rel="canonical"/>
# <meta content="article" property="og:type">
# <meta content="#6b009d" name="theme-color">
# <meta content="CurlTalk" property="og:site_name">
# <meta content="Wavemaker - stringy hair" name="twitter:title" property="og:title">
# <meta content="https://curltalk.naturallycurly.com/discussion/187776/wavemaker-stringy-hair" property="og:url">
# <meta content="Hey everyone, I have type low porosity 2A hair.  I had been experimenting with a gel for a few months and gave up on it because it weighed my hair down too …" name="description" property="og:description">
# <meta content="https://us.v-cdn.net/6030387/uploads/876f0f9e8a4f2ec070ab20ffc5190f28.png" property="og:image">
# <meta content="Hey everyone, I have type low porosity 2A hair.  I had been experimenting with a gel for a few months and gave up on it because it weighed my hair down too …" name="twitter:description"/>
# <meta content="summary" name="twitter:card"/>
# <script>gdn=window.gdn||{};gdn.meta={"ConfirmDeleteCommentHeading":"Delete Comment","ConfirmDeleteCommentText":"Are you sure you want to delete this comment?","emoji":{"assetPath":"https:\/\/curltalk.naturallycurly.com\/resources\/emoji","format":"<img class=\"emoji\" src=\"%1$s\" title=\"%2$s\" alt=\"%2$s\" height=\"20\" \/>","emoji":{"smile":"smile.png","smiley":"smiley.png","wink":"wink.png","blush":"blush.png","neutral":"neutral.png","relaxed":"relaxed.png","grin":"grin.png","joy":"joy.png","sweat_smile":"sweat_smile.png","lol":"lol.png","innocent":"innocent.png","naughty":"naughty.png","yum":"yum.png","relieved":"relieved.png","love":"love.png","sunglasses":"sunglasses.png","smirk":"smirk.png","expressionless":"expressionless.png","unamused":"unamused.png","sweat":"sweat.png","pensive":"pensive.png","confused":"confused.png","confounded":"confounded.png","kissing":"kissing.png","kissing_heart":"kissing_heart.png","kissing_smiling_eyes":"kissing_smiling_eyes.png","kissing_closed_eyes":"kissing_closed_eyes.png","tongue":"tongue.png","disappointed":"disappointed.png","worried":"worried.png","angry":"angry.png","rage":"rage.png","cry":"cry.png","persevere":"persevere.png","triumph":"triumph.png","frowning":"frowning.png","anguished":"anguished.png","fearful":"fearful.png","weary":"weary.png","sleepy":"sleepy.png","tired_face":"tired_face.png","grimace":"grimace.png","bawling":"bawling.png","open_mouth":"open_mouth.png","hushed":"hushed.png","cold_sweat":"cold_sweat.png","scream":"scream.png","astonished":"astonished.png","flushed":"flushed.png","sleeping":"sleeping.png","dizzy":"dizzy.png","no_mouth":"no_mouth.png","mask":"mask.png","star":"star.png","cookie":"cookie.png","warning":"warning.png","mrgreen":"mrgreen.png","heart":"heart.png","heartbreak":"heartbreak.png","kiss":"kiss.png","+1":"+1.png","-1":"-1.png","grey_question":"grey_question.png","trollface":"trollface.png","error":"grey_question.png"}},"DiscussionID":"187776","Category":"Hair Type 2","ShowUserReactions":"popup","keenio.projectID":"5a25a19dc9e77c000109a241","keenio.writeKey":"A7221599A669EDB1FA887BC8DF411C1A9B02D6998FC4D41F0595CF02DD7AF9396B8ECB6FAC6B93C9E7E9D8C113730163D5B88840D400C4D2540F8C987E867426FEBC8A094EB547126A641845F33709734F52DBE4737A773752D9BCD462B80792","vaCookieName":"vf_naturallycurly_SBK6E-vA","eventData":{"ip":"0.0.0.0","method":"GET","site":{"accountID":60186499,"name":"naturallycurly.vanillacommunities.com","siteID":6030387},"url":"https:\/\/curltalk.naturallycurly.com\/discussion\/187776\/wavemaker-stringy-hair","_country":"US","user":{"dateFirstVisit":null,"name":"@guest","roleType":"guest","userID":0},"userAgent":"python-requests\/2.21.0","keen":{"addons":[{"name":"keen:ip_to_geo","input":{"ip":"ip"},"output":"ipGeo"},{"name":"keen:url_parser","input":{"url":"url"},"output":"urlParsed"},{"name":"keen:ua_parser","input":{"ua_string":"userAgent"},"output":"userAgentParsed"},{"name":"keen:referrer_parser","input":{"referrer_url":"referrer","page_url":"url"},"output":"referrerParsed"}]},"discussion":{"category":{"categoryID":46,"name":"Hair Type 2","slug":"c2"},"categoryAncestors":{"cat01":{"categoryID":79,"name":"Hair Types","slug":"hair-types"},"cat02":{"categoryID":46,"name":"Hair Type 2","slug":"c2"}},"commentMetric":{"firstComment":false,"time":null},"countComments":10,"dateInserted":{"year":2018,"month":8,"day":24,"hour":2,"minute":31,"dayOfWeek":5,"startOfWeek":1534636800,"timestamp":1535077917,"timeZone":"UTC"},"discussionID":187776,"discussionType":"Question","discussionUser":{"commentCount":21,"dateFirstVisit":{"year":2018,"month":5,"day":10,"hour":22,"minute":2,"dayOfWeek":4,"startOfWeek":1525564800,"timestamp":1525989733,"timeZone":"UTC"},"dateRegistered":{"year":2018,"month":5,"day":10,"hour":22,"minute":2,"dayOfWeek":4,"startOfWeek":1525564800,"timestamp":1525989733,"timeZone":"UTC"},"discussionCount":7,"name":"Pree990","roles":[{"name":"Registered Users","roleID":2},{"name":"Curl Ambassador","roleID":12}],"roleType":"member" ...
# gdn.permissions={"permissions":{"activity.view":true,"profiles.view":true,"discussions.view":true,"badges.view":true,"discussions.add":[-1,80],"comments.add":[-1,80]},"bans":[],"isAdmin":false};
# window.__ACTIONS__=[];
# </script>
# <script src="/js/library/jquery.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/library/jquery.form.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/library/jquery.popup.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/library/jquery.popin.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/library/jquery.gardenhandleajaxform.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/library/jquery.atwho.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/global.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/flyouts.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/js/library/jquery.autosize.min.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/applications/vanilla/js/autosave.js?v=3.0.5d2f593f"></script>
# <script src="/applications/vanilla/js/discussion.js?v=3.0.5d2f593f"></script>
# <script src="/js/library/jquery-ui.min.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/plugins/Reactions/js/reactions.js?v=1.4.6.5d2f593f"></script>
# <script src="/plugins/Quotes/js/quotes.js?v=1.9.5d2f593f"></script>
# <script src="/js/library/jquery.tokeninput.js?v=3.1-2019.009.5d2f593f"></script>
# <script src="/plugins/AuthorSelector/js/authorselector.js?v=1.3.5d2f593f"></script>
# <script src="/plugins/vanillaanalytics/js/vendors/js.cookie.js?v=1.2.5d2f593f"></script>
# <script src="/plugins/vanillaanalytics/js/vendors/keen.min.js?v=1.2.5d2f593f"></script>
# <script src="/plugins/vanillaanalytics/js/keenio.min.js?v=1.2.5d2f593f"></script>
# <script src="/plugins/AdvancedSearch/js/advanced-search.js?v=1.1.5d2f593f"></script>
# <script src="/plugins/editor/js/editor.js?v=1.8.1.5d2f593f"></script>
# <script src="/plugins/editor/js/jquery.ui.widget.js?v=1.8.1.5d2f593f"></script>
# <script src="/plugins/editor/js/jquery.iframe-transport.js?v=1.8.1.5d2f593f"></script>
# <script src="/plugins/editor/js/jquery.fileupload.js?v=1.8.1.5d2f593f"></script>
# <script src="/applications/vanilla/js/spoilers.js?v=3.0.5d2f593f"></script>
# <script src="/applications/vanilla/js/tagging.js?v=3.0.5d2f593f"></script>
# <script>var supportsAllFeatures = window.Promise && window.fetch && window.Symbol&& window.CustomEvent && Element.prototype.remove && Element.prototype.closest&& window.NodeList && NodeList.prototype.forEach;if (!supportsAllFeatures) {var head = document.getElementsByTagName('head')[0];var script = document.createElement('script');script.src = 'https://curltalk.naturallycurly.com/dist/polyfills.min.js?h=5d2f593f';head.appendChild(script);} else {  }</script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/api/v2/locales/en/translations.js?h=5d2f593f"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/runtime.min.js?h=5d2f593f"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/vendors.min.js?h=5d2f593f"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/shared.min.js?h=5d2f593f"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/addons/rich-editor.min.js?h=5d2f593f"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/addons/dashboard.min.js?h=5d2f593f"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/bootstrap.min.js?h=5d2f593f"></script>
# <script type="application/ld+json">{"headline":"Wavemaker - stringy hair","description":"Hey everyone, I have type low porosity 2A hair.\u00a0 I had been experimenting with a gel for a few months and gave up on it because it weighed my hair down too much ( I tried Miss Jessie's Jelly Soft Curls and LA Looks which looked nice if a diffused but otherwise it felt like it weighed my hair down).\u00a0\u00a0 I moved onto Devacurl Wavemaker because I read a lot of good things about it.\u00a0 My hair looked really good when I tried a sample of it about 5 months ago but I've been finding that my hair looks str\u2026","discussionUrl":"https:\/\/curltalk.naturallycurly.com\/discussion\/187776\/wavemaker-stringy-hair","dateCreated":"2018-08-24 02:31:57","author":{"@context":"https:\/\/schema.org","@type":"Person","name":"Pree990","image":"https:\/\/us.v-cdn.net\/6030387\/uploads\/defaultavatar\/nXRNW71VRPDDU.jpg","url":"https:\/\/curltalk.naturallycurly.com\/profile\/Pree990"},"@context":"https:\/\/schema.org","@type":"DiscussionForumPosting"}</script>
# <link href="https://www.naturallycurly.com/css/app.css?id=75d11e028136b20c36dc" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/system-alerts/css/index.css?id=bee82e70ef295e22bb71" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/css/index.css?id=29ad982865bba35342db" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/with-images/css/index.css?id=08e5dae4897d7fa929ae" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/with-columns/css/index.css?id=181b8cf4f3255c2b70cf" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/detailed-list/css/index.css?id=40faf08d1053cbf0d5cb" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/dropdown-menu/css/index.css?id=40faf08d1053cbf0d5cb" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/css/index.css?id=bc55415dd77e8f09f1af" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/login/css/index.css?id=eaba96cc36cf17352583" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/search-bar/css/index.css?id=fcc7b359def1f7f41bac" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/shopping-cart/css/index.css?id=13aa1754c79dba962603" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/subscribe/css/index.css?id=d150abad71a0439f72be" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/features/css/index.css?id=d4b14d61b68b70ab7d75" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/css/index.css?id=862ceb4808d65390dd0c" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/page-layouts/vanilla-forums-default-plain/css/index.css?id=e627191e9a199029bc1b" rel="stylesheet"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-477881-3"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-477881-3', {
#                 'optimize_id': 'GTM-P86LPBZ',
#         'page_title':'',
#         'page_path':''
#     });
#
#
#
#     </script>
# <script> !function(f,b,e,v,n,t,s) {if(f.fbq)return;n=f.fbq=function(){n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}; if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0'; n.queue=[];t=b.createElement(e);t.async=!0; t.src=v;s=b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t,s)}(window,document,'script', 'https://connect.facebook.net/en_US/fbevents.js'); fbq('init', '369905576513231'); fbq('track', 'PageView'); </script>
# <script type="text/javascript">
# (function(d,s,i,r) {
#   if (d.getElementById(i)){return;}
#   var n=d.createElement(s),e=d.getElementsByTagName(s)[0];
#   n.id=i;n.src='//js.hs-analytics.net/analytics/'+(Math.ceil(new Date()/r)*r)+'/2272072.js';
#   e.parentNode.insertBefore(n, e);
# })(document,"script","hs-analytics",300000);
# </script>
# <script async="async" src="//cdn.adsafeprotected.com/iasPET.1.js"></script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().setTargeting('path', 'vanilla-forums');
#                 googletag.pubads().setTargeting('URL', 'vanilla-forums/master-template');
#                 googletag.pubads().setTargeting('env', 'www');
#     });
#
#     var dfpAdSlots = {};
#     var initDfpAdsFunctions = {};
# </script>
# <!--[if lte IE 8]>
# <script charset="utf-8" type="text/javascript" src="//js.hsforms.net/forms/v2-legacy.js"></script>
# <![endif]-->
# <script charset="utf-8" src="//js.hsforms.net/forms/v2.js" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/js/DianaApi.js" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/js/DianaApiClient.js" type="text/javascript"></script>
# </meta></meta></meta></meta></meta></meta></meta></head>
# <body class="Vanilla Discussion isDesktop index Question Section-Discussion Section-Category-c2 vanilla-forums-default-plain sticky-header-body" id="vanilla_discussion_index">
# <div class="alerts-container">
# </div>
# <div class="alert-template">
# <div aria-atomic="true" aria-live="assertive" class="system-alert card" role="alert">
# <div class="card-body">
# <div class="alert-header-container card-title">
# <div class="alert-title-container">
# <i class="fas fa-bell alert-icon-success mr-2"></i>
# <i class="fas fa-bell alert-icon-error mr-2"></i>
# <strong class="mr-auto alert-title"></strong>
# <small class="text-muted alert-title-date"></small>
# </div>
# <div aria-label="Close" class="ml-2 mb-1 alert-close-btn">
# <i class="fas fa-times"></i>
# </div>
# </div>
# <div class="alert-body card-text">
# </div>
# </div>
# </div></div>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.10&appId=244330805725130";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <div class="navbar-custom">
# <div class="container-fluid banner-top nct-banner">
# <div class="row justify-content-center leaderboard-container">
# <div class="google-dfp-adspace" data-ad-rendered-sizes="[[1, 1], [300, 250], [970, 250], [300, 600], [320, 50], [970, 90], [728, 90]]" data-ad-sizes="responsive-full-page-banner-top-ad" data-ad-slot="googletag" data-ad-url="/21698916284/naturallycurly/topics" id="NC_T"></div>
# </div>
# </div>
# <div class="fixed-menu">
# <div class="row mx-0 background-content">
# <nav class="navbar navbar-expand-lg collapse-sidebar">
# <div class="navbar-top-part row">
# <div class="col-2">
# <div class="navbar-left-container">
# <a class="navbar-logo-container" href="https://www.naturallycurly.com">
# <img class="nc-logo" src="https://www.naturallycurly.com/img/naturallycurly.png"/>
# </a>
# <button class="main-menu-button-mobile navbar-toggler">
# <i class="fa fa-bars">
# <mark class="number-notifications"></mark>
# </i>
# </button>
# </div>
# </div>
# <div class="col-8 col-sm-9 col-xl-8">
# <div class="navbar-center-container">
# <a class="navbar-logo-container" href="https://www.naturallycurly.com">
# <img class="nc-logo" src="https://www.naturallycurly.com/img/naturallycurly.png"/>
# </a>
# <div class="navbar-items-container">
# <ul class="navbar-nav">
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/quiz" id="navbarDropdown0">
# TEXTURE
# </a>
# <div aria-labelledby="menu-texture" class="dropdown-menu nc-dropdown-menu sidebar-menu with-images">
# <div class="dropdown-menu-submenu nc-dropdown-menu-submenu with-images-submenu">
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <span class="dropdown-title nc-dropdown-title">WAVY (2a-2c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a loose “S” very easily straightened</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2a-720x864.jpg">
# </img></div>
# <span class="image-label">2a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2b-720x864.jpg">
# </img></div>
# <span class="image-label">2b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2c-720x864.jpg"/>
# </div>
# <span class="image-label">2c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <span class="dropdown-title nc-dropdown-title">CURLY (3a-3c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a definite “S” shaped like a corkscrew</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3a-720x864.jpg"/>
# </div>
# <span class="image-label">3a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3b-720x864.jpg"/>
# </div>
# <span class="image-label">3b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3c-720x864.jpg"/>
# </div>
# <span class="image-label">3c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <span class="dropdown-title nc-dropdown-title">COILY (4a-4c)</span>
# <span class="dropdown-description nc-dropdown-description">Very tight curl when stretched creates an “S”</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4a-720x864.jpg"/>
# </div>
# <span class="image-label">4a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4b-720x864.jpg"/>
# </div>
# <span class="image-label">4b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4c-720x864.jpg"/>
# </div>
# <span class="image-label">4c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <span class="dropdown-title nc-dropdown-title">LOCS</span>
# <span class="dropdown-description nc-dropdown-description">Hair intentionally matted to form "ropes"</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/ljbRc5dYtPNc1537231421.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/quiz">
# <span class="dropdown-title nc-dropdown-title">QUIZ</span>
# <span class="dropdown-description nc-dropdown-description">Take our quiz to learn your curl pattern</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/quiz">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/Zosdxmktbe7i1537230313.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/curlreading" id="navbarDropdown1">
# <div class="columns-menu">TOPICS</div>
# </a>
# <div class="dropdown-menu nc-dropdown-menu large-menu with-columns">
# <div class="nc-dropdown-menu-submenu">
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CONCERNS</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/dryness" id="dryness">Dryness</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/frizz-control" id="frizz">Frizz</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curl-definition" id="curl-definition">Curl Definition</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/detangling" id="detangling">Detangling</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-growth" id="hair-growth">Hair Growth</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/breakage" id="hair-breakage">Hair Breakage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/shrinkage" id="shrinkage">Shrinkage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hair-loss" id="hair-loss">Hair Loss</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/scalp-care" id="scalp-care">Scalp Care</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/heat-damage" id="heat-damage">Heat Damage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/graying" id="graying">Graying</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/volume" id="volume">Volume</a></li>
# </ul>
# </div>
# </div>
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CURL CARE</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-color" id="hair-color">Hair Color</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/haircuts" id="haircuts">Haircuts</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hairstyles" id="hairstyles">Hairstyles</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/transitioning" id="transitioning">Transitioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/straightening" id="straightening">Straightening</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/retexturizing" id="retexturizing">Retexturizing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curly-girl-method" id="curly-girl-method">Curly Girl Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/l-o-c-method" id="loc-method">LOC Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/second-day-hair" id="2nd-day-hair">2nd Day Hair</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/cleansing" id="cleansing">Cleansing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/conditioning" id="conditioning">Conditioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/for-kids" id="kids">Kids</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/for-men" id="men">Men</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/salons" id="salon-finder">Salon Finder</a></li>
# </ul>
# </div>
# </div>
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">LIFESTYLE</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/celebrities" id="celebrities">Celebrities</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/beauty" id="beauty">Beauty</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/self-care" id="self-care">Self-Care</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/culture" id="culture">Culture</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/business" id="business">Business</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.naturallycurly.com/videos" id="navbarDropdown2">
# VIDEOS
# </a>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/curlreading/product" id="navbarDropdown3">
# PRODUCTS
# </a>
# <div aria-labelledby="navbarDropdown3" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curlreading/product">
# <span class="dropdown-title nc-dropdown-title">TOP PRODUCTS</span>
# <span class="dropdown-description nc-dropdown-description">Guides and resources for easy product selection</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curlreading/ingredients">
# <span class="dropdown-title nc-dropdown-title">INGREDIENTS</span>
# <span class="dropdown-description nc-dropdown-description">Learn how to read your hair product labels</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curlreading/latest-diy-products">
# <span class="dropdown-title nc-dropdown-title">DIY PRODUCTS</span>
# <span class="dropdown-description nc-dropdown-description">Easy-to-make recipes for all your haircare needs</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/editors-choice">
# <span class="dropdown-title nc-dropdown-title">EDITORS' CHOICE</span>
# <span class="dropdown-description nc-dropdown-description">Our editors share their top hair and skincare products</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curly-hair/awards">
# <span class="dropdown-title nc-dropdown-title">BEST OF THE BEST</span>
# <span class="dropdown-description nc-dropdown-description">Community member favorites make up this coveted list</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/giveaways">
# <span class="dropdown-title nc-dropdown-title">GIVEAWAYS</span>
# <span class="dropdown-description nc-dropdown-description">Enter to win products we all love</span>
# </a>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://curltalk.naturallycurly.com/" id="navbarDropdown4" target="_blank">
# COMMUNITY
# </a>
# <div aria-labelledby="navbarDropdown4" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/stylenook">
# <span class="dropdown-title nc-dropdown-title">STYLENOOK</span>
# <span class="dropdown-description nc-dropdown-description">Share your style and browse the style of others</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://curltalk.naturallycurly.com/" target="_blank">
# <span class="dropdown-title nc-dropdown-title">CURLTALK</span>
# <span class="dropdown-description nc-dropdown-description">Chat with curl friends about your favorite curly topics</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://trendsetter.naturallycurly.com/" target="_blank">
# <span class="dropdown-title nc-dropdown-title">TRENDSETTER</span>
# <span class="dropdown-description nc-dropdown-description">Participate in product testing surveys discussions etc.</span>
# </a>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://shop.naturallycurly.com/" id="navbarDropdown5" target="_blank">
# SHOP
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.naturallycurly.com/contact" id="navbarDropdown6">
# <div class="purple-text">GET INVOLVED</div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.essence.com" id="navbarDropdown7" target="_blank">
# <div class="purple-text">ESSENCE.COM</div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-2 col-sm-1 col-xl-2">
# <div class="navbar-right-container">
# <div class="navbar-items-container">
# <ul class="navbar-nav">
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbarDropdown8">
# <div class="child-right-container" id="shopping-cart-button"><i class="fas fa-shopping-cart"><mark class="number-cart-items"></mark></i> <span class="menu-text">My Cart</span></div>
# </a>
# <div aria-labelledby="navbarDropdown8" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="javascript:void(0)">
# <span class="dropdown-title nc-dropdown-title"><div id="shopping-cart-container"></div></span>
# <span class="dropdown-description nc-dropdown-description"></span>
# </a>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbarDropdown9">
# <div class="child-right-container" id="subscribe-button"><i class="far fa-envelope"></i> <span class="menu-text">SUBSCRIBE</span></div>
# </a>
# <div aria-labelledby="navbarDropdown9" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="javascript:void(0)">
# <span class="dropdown-title nc-dropdown-title"><div id="subscribe-form-container"></div></span>
# <span class="dropdown-description nc-dropdown-description"></span>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="navbar-bottom-part">
# <ul class="subnavbar-nav">
# <li class="subnavbar-item">
# <a class="subnav-link" href="javascript:void(0)" id="navbarDropdown10">
# <div class="features-label">features:</div>
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/texture-tales" id="navbarDropdown11">
# TEXTURE TALES
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/leaders-in-curl" id="navbarDropdown12">
# LEADERS IN CURL
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/fresh-friday" id="navbarDropdown13">
# FRESH FRIDAY
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/curlreading/texture-on-the-runway" id="navbarDropdown14">
# TEXTURE ON THE RUNWAY
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="javascript:void(0)" id="navbarDropdown15">
# <div id="search-form-container"></div>
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="/login?redirectTo=https://curltalk.naturallycurly.com" id="navbarDropdown16-login" target="_blank">
# <div id="menu-login-container"></div>
# </a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="collapse navbar-collapse" id="navbarCollapser">
# <div class="navbar-sidebar-menu">
# <div class="navbar-items-container">
# <ul class="navbar-nav">
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/quiz" id="navbarDropdown0">
# TEXTURE
# </a>
# <div aria-labelledby="menu-texture" class="dropdown-menu nc-dropdown-menu sidebar-menu with-images">
# <div class="dropdown-menu-submenu nc-dropdown-menu-submenu with-images-submenu">
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <span class="dropdown-title nc-dropdown-title">WAVY (2a-2c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a loose “S” very easily straightened</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2a-720x864.jpg"/>
# </div>
# <span class="image-label">2a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2b-720x864.jpg"/>
# </div>
# <span class="image-label">2b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2c-720x864.jpg"/>
# </div>
# <span class="image-label">2c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <span class="dropdown-title nc-dropdown-title">CURLY (3a-3c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a definite “S” shaped like a corkscrew</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3a-720x864.jpg"/>
# </div>
# <span class="image-label">3a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3b-720x864.jpg"/>
# </div>
# <span class="image-label">3b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3c-720x864.jpg"/>
# </div>
# <span class="image-label">3c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <span class="dropdown-title nc-dropdown-title">COILY (4a-4c)</span>
# <span class="dropdown-description nc-dropdown-description">Very tight curl when stretched creates an “S”</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4a-720x864.jpg"/>
# </div>
# <span class="image-label">4a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4b-720x864.jpg"/>
# </div>
# <span class="image-label">4b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4c-720x864.jpg"/>
# </div>
# <span class="image-label">4c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <span class="dropdown-title nc-dropdown-title">LOCS</span>
# <span class="dropdown-description nc-dropdown-description">Hair intentionally matted to form "ropes"</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/ljbRc5dYtPNc1537231421.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/quiz">
# <span class="dropdown-title nc-dropdown-title">QUIZ</span>
# <span class="dropdown-description nc-dropdown-description">Take our quiz to learn your curl pattern</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/quiz">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/Zosdxmktbe7i1537230313.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/curlreading" id="navbarDropdown1">
# <div class="columns-menu">TOPICS</div>
# </a>
# <div class="dropdown-menu nc-dropdown-menu large-menu with-columns">
# <div class="nc-dropdown-menu-submenu">
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CONCERNS</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/dryness" id="dryness">Dryness</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/frizz-control" id="frizz">Frizz</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curl-definition" id="curl-definition">Curl Definition</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/detangling" id="detangling">Detangling</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-growth" id="hair-growth">Hair Growth</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/breakage" id="hair-breakage">Hair Breakage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/shrinkage" id="shrinkage">Shrinkage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hair-loss" id="hair-loss">Hair Loss</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/scalp-care" id="scalp-care">Scalp Care</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/heat-damage" id="heat-damage">Heat Damage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/graying" id="graying">Graying</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/volume" id="volume">Volume</a></li>
# </ul>
# </div>
# </div>
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CURL CARE</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-color" id="hair-color">Hair Color</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/haircuts" id="haircuts">Haircuts</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hairstyles" id="hairstyles">Hairstyles</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/transitioning" id="transitioning">Transitioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/straightening" id="straightening">Straightening</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/retexturizing" id="retexturizing">Retexturizing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curly-girl-method" id="curly-girl-method">Curly Girl Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/l-o-c-method" id="loc-method">LOC Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/second-day-hair" id="2nd-day-hair">2nd Day Hair</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/cleansing" id="cleansing">Cleansing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/conditioning" id="conditioning">Conditioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/for-kids" id="kids">Kids</a></li>
# <li class="nc-dropdown-list-item">
# ...
#                     " target="_blank">
# <span class="fa-stack fa-lg">
# <i class="fa fa-circle fa-stack-2x"></i>
# <i class="fab fa-youtube fa-stack-1x fa-inverse"></i>
# </span>
# </a>
# </div>
# <div>
# <a class="email" href="/cdn-cgi/l/email-protection#2c6f434242494f586c424d58595e4d4040554f595e4055024f4341" onclick="
#                                                                                                         return true;
#                     " target="_blank">
# <span class="fa-stack fa-lg">
# <i class="fa fa-circle fa-stack-2x"></i>
# <i class="far fa-envelope fa-stack-1x fa-inverse"></i>
# </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="text-center mt-4 copyright">
# © 2019 NaturallyCurly
# </div>
# </div>
# </footer>
# <div class="login-menu-templates">
# <div class="member-menu-container">
# <div class="user-navbar-menu">
# </div>
# <div class="user-logged-submenu">
# <div class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="/my-account">
# <span class="dropdown-title nc-dropdown-title">Edit My Account</span>
# </a>
# <a class="dropdown-item nc-dropdown-item profile-link" href="/user/view/username/">
# <span class="dropdown-title nc-dropdown-title">View My Public Profile</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="/logout">
# <span class="dropdown-title nc-dropdown-title">Logout</span>
# </a>
# </div>
# </div>
# </div>
# </div> <div class="visitor-menu-container">
# <div class="user-navbar-menu">
# <div class="login-menu-btn" data-toggle="tooltip" title="Login">
# <i class="far fa-user-circle"></i><span class="login-text">Login</span>
# </div>
# </div>
# </div> </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="https://www.naturallycurly.com/js/app.js?id=0af96f538355dfe63c64"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/system-alerts/js/index.js?id=9a2b703c55c630ed81b6" type="text/javascript"></script>
# <script>
#         var csrfToken = "r8espbQAjIbeGDwID6nId4gRNQr3p6uaawtkpKQI";
#         var navbarPosition = 0;
#         var fixedMenu = null;
#         var navbarPlaceholder = null;
#         var windowWidth = $(window).width();
#         var isDesktop = false;
#
#         if (windowWidth > 990) {
#             isDesktop = true;
#         }
#
#         $(document).ready(function(){
#             initialConfig();
#             events();
#         });
#
#         function initialConfig(){
#             //We save the menu without the top ad
#             fixedMenu = $(".fixed-menu").first();
#
#             //We create the placeholder for avoid jumpiness when navbar is sticky
#             fixedMenu.wrap('<div class="nav-placeholder"></div>');
#             navbarPlaceholder = $(".nav-placeholder");
#             //We set to the placeholder the same height that the navbar
#             navbarPlaceholder.height(fixedMenu.outerHeight());
#             //We save the navbar position
#             navbarPosition = navbarPlaceholder.offset().top;
#         }
#
#         //(Only desktop function) this function hides the navbar extra content (featured menu and top ad)
#         function slideUpNavbarExtraContent(){
#             let featuredMenu = $(".navbar-bottom-part").first();
#             featuredMenu.slideUp();
#         }
#
#         //(Only desktop function) this function shows the navbar extra content (featured menu and top ad)
#         function slideDownNavbarExtraContent(){
#             let featuredMenu = $(".navbar-bottom-part").first();
#             featuredMenu.slideDown();
#         }
#
#         //Listener called when the Top ad is renderer
#         function navbarAdSlotRenderEndedListener(){
#             //We update the navbar position
#             navbarPosition = navbarPlaceholder.offset().top;
#         }
#
#         function events(){
#             $(window).on('scroll', function() {
#                 checkStickyNavbar();
#             });
#         }
#
#         function checkStickyNavbar(){
#             //Check the navbar stickiness
#             if (window.pageYOffset >= navbarPosition) {
#                 fixedMenu.addClass("sticky");
#             } else {
#                 fixedMenu.removeClass("sticky");
#             }
#
#             if(isDesktop){
#                 //400px after the navbar position we hide the extra-content
#                 if (window.pageYOffset >= navbarPosition + 400) {
#                     slideUpNavbarExtraContent();
#                 }
#                 else{
#                     slideDownNavbarExtraContent();
#                 }
#             }
#         }
#     </script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/js/index.js?id=0ba834f2665c88275e54" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/login/js/index.js?id=006265caa8a714a57d5e" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/search-bar/js/index.js?id=34d258b1afcca741dfc8" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/shopping-cart/js/index.js?id=a6912632f7d467c8376c" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/subscribe/js/index.js?id=975a2c737900651fdb1f" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/features/js/index.js?id=f21ff9c1b82f82afe058" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/js/index.js?id=8cb9b6c08927ac7dc7cf" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/page-layouts/vanilla-forums-default-plain/js/index.js?id=e351f3eb460d64cfe2c4" type="text/javascript"></script>
# <script>
#         initDfpAdsFunctions['NC_T'] = function () {
#             googletag.cmd.push(function () {
#                 var mySizeMap_NC_T = googletag.sizeMapping()
#                                     .addSize([1024, 0], [[970, 250], [970, 90], [728, 90]])
#                                     .addSize([980, 0], [[728, 90]])
#                                     .addSize([640, 0], [468, 60])
#                                     .addSize([0, 0], [[320, 50], [300, 250], [300, 50]])
#                                     .build();
#
#                                     dfpAdSlots["NC_T"] = googletag.defineSlot('/21698916284/naturallycurly/topics', [[1, 1], [300, 250], [970, 250], [300, 600], [320, 50], [970, 90], [728, 90]], 'NC_T')
#                         .defineSizeMapping(mySizeMap_NC_T)
#                         .addService(googletag.pubads())
#                         .setTargeting("pos", "1")
#                         .setTargeting("tile", "1");
#
#                                     googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#                         if (event.slot === dfpAdSlots["NC_T"]) {
#                             navbarAdSlotRenderEndedListener();
#                         }
#                     });
#
#             });
#         }
#     </script>
# <script>
#         initDfpAdsFunctions['NC_B'] = function () {
#             googletag.cmd.push(function () {
#                 var mySizeMap_NC_B = googletag.sizeMapping()
#                                     .addSize([1024, 0], [[970, 250], [970, 90], [728, 90]])
#                                     .addSize([980, 0], [[728, 90]])
#                                     .addSize([640, 0], [468, 60])
#                                     .addSize([0, 0], [[320, 50], [300, 50]])
#                                     .build();
#
#
#                     dfpAdSlots["NC_B"] = googletag.defineSlot('/21698916284/naturallycurly/topics', [[1, 1], [300, 250], [970, 250], [300, 600], [320, 50], [970, 90], [728, 90]], 'NC_B')
#                         .defineSizeMapping(mySizeMap_NC_B)
#                         .addService(googletag.pubads())
#                                                 .setTargeting("tile", "4");
#
#
#             });
#         }
#     </script>
# <script>
#             $.noConflict(true);
#         </script>
# <div aria-hidden="true" aria-labelledby="disableAdBlockerTitle" class="modal fade" id="disableAdBlockerContainer" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <div class="row">
# <img class="nc-img col-6" src="https://www.naturallycurly.com/img/naturallycurly.svg"/>
# <div class="col-6 d-flex">
# <h5 class="modal-title align-self-center" id="disableAdBlockerTitle"> team message</h5>
# </div>
# </div>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body text-center">
# Our website is made possible by displaying online advertisements to our visitors.<br/>
# Please consider supporting us by disabling your ad blocker on our website.
# <br/><br/>
# Thank you! :)
# </div>
# </div>
# </div>
# </div>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/blockadblock/3.2.1/blockadblock.min.js"></script>
# <script>
#     function requestAds() {
#         googletag.cmd.push(function() {
#
#             googletag.pubads().enableLazyLoad({
#                 fetchMarginPercent: 100,  // Fetch slots within 1 viewports.
#                 renderMarginPercent: 0,  // Render slots within 0 viewports.
#                 mobileScaling: 2.0  // Double the above values on mobile.
#             });
#
#             // Configure SRA
#             googletag.pubads().enableSingleRequest();
#
#             googletag.enableServices();
#
#             document.body.querySelectorAll('div[data-ad-slot]').forEach(function(element) {
#                 googletag.display(element.id);
#             })
#
#         });
#     }
#
#     // Function called if AdBlock is not detected
#     function adBlockNotDetected() {
#     }
#     // Function called if AdBlock is detected
#     function adBlockDetected() {
#         $("#disableAdBlockerContainer").modal('show');
#     }
#
#     function checkAdblock(){
#         // Recommended audit because AdBlock lock the file 'blockadblock.js'
#         // If the file is not called, the variable does not exist 'blockAdBlock'
#         // This means that AdBlock is present
#         if(typeof blockAdBlock === 'undefined') {
#             adBlockDetected();
#         } else {
#             blockAdBlock.onDetected(adBlockDetected);
# 	        blockAdBlock.onNotDetected(adBlockNotDetected);
#         }
#     }
#
#     $(document).ready(function(){
#         checkAdblock();
#     });
# </script>
# <script type="text/javascript">
# var iasDataHandler, __iasPET = __iasPET || {};
# __iasPET.queue = __iasPET.queue || [];
# __iasPET.pubId = '929481';
#
# var IASPET_TIMEOUT = 2000;
# var __iasPETTimeoutRequestAds = setTimeout(requestAds, IASPET_TIMEOUT);
#
# var iasDataHandler = function(adSlotData) {
# 	clearTimeout(__iasPETTimeoutRequestAds);
# 	__iasPET.setTargetingForGPT();
# 	requestAds();
# };
# </script>
# <script>
#
# //
# document.addEventListener('rendered_ads', function(e){
# 	// make the PET request
# 	googletag.cmd.push(function() {
# 		// read the currently defined GPT ad slots for sending to the PET endpoint
# 		// defined all GPT ad slots before calling PET
# 		var gptSlots = googletag.pubads().getSlots();
# 		//debugger;
# 		var iasPETSlots = [];
#
# 		for (var i = 0; i < gptSlots.length; i++) {
# 			var sizes = gptSlots[i].getSizes().map(function(size) {
# 				if (size.getWidth && size.getHeight)
# 					return [size.getWidth(), size.getHeight()];
# 				else
# 					return [1, 1];
# 			});
#
# 			iasPETSlots.push({
# 				adSlotId: gptSlots[i].getSlotElementId(),
# 				//size: can either be a single size (for example, [728, 90])
# 				// or an array of sizes (for example, [[728, 90], [970, 90]])
# 				size: sizes,
# 				adUnitPath: gptSlots[i].getAdUnitPath()
# 			});
# 		}
#
# 		// make the request to PET. if your page makes multiple ad requests to DFP
# 		// (for example, lazily loaded ads, infinite scrolling pages, etc.), make
# 		// a request to PET before every request to DFP
# 		__iasPET.queue.push({
# 			adSlots: iasPETSlots,
# 			dataHandler: iasDataHandler
# 		});
# 	});
#
# }, false);
# </script>
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "25511342" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=25511342&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script type="text/javascript">
#   var _qevents = _qevents || [];
#   (function(d, s, l, t) {
#     var elem = d.createElement(s); elem.src = (d.location.protocol == "https:" ? "https://secure" : "http://edge") + l;
#     elem.async = true; elem.type = t; var scpt = document.getElementsByTagName(s)[0];
#     scpt.parentNode.insertBefore(elem, scpt);
#   })(document, "script", ".quantserve.com/quant.js", "text/javascript");
# </script>
# <script type="text/javascript">
#   /* <![CDATA[ */
#     var google_conversion_id = 1067298743;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#   /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript"></script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1067298743/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <script>
#     var windowWidth = $(window).width();
#     var isDesktop = false;
#
#     if (windowWidth > 990) {
#         isDesktop = true;
#     }
#
#     function checkInitDfpFunctionAndRun(name){
#         if(initDfpAdsFunctions[name]){
#             initDfpAdsFunctions[name]();
#         }
#
#         delete initDfpAdsFunctions[name];
#     }
#
#     function showAdsArticleGrid(){
#         //We render the NC_TR ads depending the screensize
#         //extra large screens
#         if(windowWidth > 1400){
#             checkInitDfpFunctionAndRun("NC_TR_0");
#         }
#         //large screens
#         else if(windowWidth > 1200){
#             checkInitDfpFunctionAndRun("NC_TR_1");
#         }
#         //medium screens
#         else if(windowWidth > 992){
#             checkInitDfpFunctionAndRun("NC_TR_2");
#         }
#         //small and extra small screens
#         else{
#             checkInitDfpFunctionAndRun("NC_TR_3");
#         }
#
#         //we remove all the functions for avoid run any in the for
#         delete initDfpAdsFunctions["NC_TR_0"];
#         delete initDfpAdsFunctions["NC_TR_1"];
#         delete initDfpAdsFunctions["NC_TR_2"];
#         delete initDfpAdsFunctions["NC_TR_3"];
#     }
#
#     $(document).ready(function(){
#         checkInitDfpFunctionAndRun("NC_T");
#         if(!isDesktop){
#             checkInitDfpFunctionAndRun("NC_B");
#         }
#         checkInitDfpFunctionAndRun("NC_TR");
#         showAdsArticleGrid();
#         checkInitDfpFunctionAndRun("NC_BR");
#         if(isDesktop){
#             checkInitDfpFunctionAndRun("NC_B");
#         }
#
#         for(let functionName in initDfpAdsFunctions){
#             initDfpAdsFunctions[functionName]();
#         }
#
#         var event = document.createEvent('Event');
#         event.initEvent('rendered_ads', true, true);
#
#         document.dispatchEvent(event);
#     });
# </script>
# </body>
# </html>>

# %%
signature = soup.find_all('div', class_="Signature UserSignature userContent")
signature
# Out:
# [<div class="Signature UserSignature userContent"><b>Low poo: </b>Intelligent Nutrients (IN) Harmonic; Oribe Cleansing Creme<br/>
#  <b>RO: </b>IN Harmonic<br/>
#  <b>LI: </b>CJ Beauticurls; Jessicurl (JC) Gelebration Spray<br/><b>DC: </b>JC Deep Conditioning Treatment; Weleda Rosemary Conditioning Oil<br/>
#  <b>Stylers: </b>JC Confident Coils; IN Volumizing Spray; IN Perfect Hold Hairspray; John Masters Sea Mist; Bumble Bb. Gel; Kenra Firm-Hold Gel; Sevi Blue Yarrow Sea Salt Spray<br/>
#  Low-porosity 2a/b baby-fine hair</div>,
#  <div class="Signature UserSignature userContent">Current 2B/2C Routine:<br/><b>Cleanse - </b> NYM Curl Talk Shampoo or NYM Clean Freak Cleansing Conditioner<br/><b>Condition - </b>Elucence Moisure Balance Conditioner<br/><b>Treatments - </b>Olaplex (step 3) or Elucence Moisture Repair Treatment<br/><b>Style -  </b>Briogeo Rosarco Milk Leave In + AG Re:Coil<br/><br/></div>,
#  <div class="Signature UserSignature userContent"><b>2C/3A</b> long hair with some 3C thrown in<br/><b>High Porosity, dense, coarse hair</b><br/>I make my own protein masks</div>,
#  <div class="Signature UserSignature userContent"><b>2C/3A</b> long hair with some 3C thrown in<br/><b>High Porosity, dense, coarse hair</b><br/>I make my own protein masks</div>,
#  <div class="Signature UserSignature userContent">2C Fine, long hair, a ton of it. Blonde balayage. East Coast Canadian. <br/><br/>Wash: Live Clean Fresh Water Hydrating Shampoo<br/>Monthly Scalp Cleanse: Baking Soda/Conditioner/Peppermint Essential Oil<br/>CO: Garnier Whole Blends Legendary Olive Conditioner<br/>
#  Styling: Devacurl Volumizing Foam, Devacurl Wave Maker, Garnier Curl Treat Jelly<br/>Refresh Day: Klorane Dry Shampoo with Nettle, Devacurl Supercream<br/>Deep Condition: Shea Moisture Manuka Honey &amp; Yogurt Treatment<br/><br/>My whole wash routine is upside-down... detangling, rinsing, applying products, scrunching, diffusing... the bigger the waves, the better!  </div>]

# %% [markdown]
# ### Got all of the URLs for each main category
# Saved as the variable category

# %%
user_agent =  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
html_page = requests.get('https://curltalk.naturallycurly.com/', headers = {'User-Agent': user_agent} ) #Make a get request to retrieve the page
soup2 = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing
#soup2.prettify

# %%
signature = soup.find_all('div', class_="col content")
#signature

# %%
signature2 = soup.find_all('div', class_="CategoryGroup"*)
signature2
# Out:
#   File "<ipython-input-4-259a6d171564>", line 1
#     signature2 = soup.find_all('div', class_="CategoryGroup"*)
#                                                              ^
# SyntaxError: invalid syntax

# %%
for link in soup2.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.naturallycurly.com
# https://www.naturallycurly.com
# https://www.naturallycurly.com/quiz
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/locs
# https://www.naturallycurly.com/curly-hair/locs
# https://www.naturallycurly.com/quiz
# https://www.naturallycurly.com/quiz
# https://www.naturallycurly.com/curlreading
# https://www.naturallycurly.com/curlreading/dryness
# https://www.naturallycurly.com/curlreading/frizz-control
# https://www.naturallycurly.com/curlreading/curl-definition
# https://www.naturallycurly.com/curlreading/detangling
# https://www.naturallycurly.com/curly-hair/hair-growth
# https://www.naturallycurly.com/curlreading/breakage
# https://www.naturallycurly.com/curlreading/shrinkage
# https://www.naturallycurly.com/curlreading/hair-loss
# https://www.naturallycurly.com/curlreading/scalp-care
# https://www.naturallycurly.com/curlreading/heat-damage
# https://www.naturallycurly.com/curlreading/graying
# https://www.naturallycurly.com/curlreading/volume
# https://www.naturallycurly.com/curly-hair/hair-color
# https://www.naturallycurly.com/curlreading/haircuts
# https://www.naturallycurly.com/curlreading/hairstyles
# https://www.naturallycurly.com/curly-hair/transitioning
# https://www.naturallycurly.com/curlreading/straightening
# https://www.naturallycurly.com/curlreading/retexturizing
# https://www.naturallycurly.com/curlreading/curly-girl-method
# https://www.naturallycurly.com/curlreading/l-o-c-method
# https://www.naturallycurly.com/curlreading/second-day-hair
# https://www.naturallycurly.com/curlreading/cleansing
# https://www.naturallycurly.com/curlreading/conditioning
# https://www.naturallycurly.com/curly-hair/for-kids
# https://www.naturallycurly.com/curly-hair/for-men
# https://www.naturallycurly.com/salons
# https://www.naturallycurly.com/curlreading/celebrities
# https://www.naturallycurly.com/curlreading/beauty
# https://www.naturallycurly.com/curlreading/self-care
# https://www.naturallycurly.com/curlreading/culture
# https://www.naturallycurly.com/curlreading/business
# https://www.naturallycurly.com/videos
# https://www.naturallycurly.com/curlreading/product
# https://www.naturallycurly.com/curlreading/product
# https://www.naturallycurly.com/curlreading/ingredients
# https://www.naturallycurly.com/curlreading/latest-diy-products
# https://www.naturallycurly.com/editors-choice
# https://www.naturallycurly.com/curly-hair/awards
# https://www.naturallycurly.com/giveaways
# https://curltalk.naturallycurly.com/
# https://www.naturallycurly.com/stylenook
# https://curltalk.naturallycurly.com/
# https://trendsetter.naturallycurly.com/
# https://shop.naturallycurly.com/
# https://www.naturallycurly.com/contact
# https://www.essence.com
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# https://www.naturallycurly.com/texture-tales
# https://www.naturallycurly.com/leaders-in-curl
# https://www.naturallycurly.com/fresh-friday
# https://www.naturallycurly.com/curlreading/texture-on-the-runway
# javascript:void(0)
# /login?redirectTo=https://curltalk.naturallycurly.com
# https://www.naturallycurly.com/quiz
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/waves
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/curls
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/coils
# https://www.naturallycurly.com/curly-hair/locs
# https://www.naturallycurly.com/curly-hair/locs
# https://www.naturallycurly.com/quiz
# https://www.naturallycurly.com/quiz
# https://www.naturallycurly.com/curlreading
# https://www.naturallycurly.com/curlreading/dryness
# https://www.naturallycurly.com/curlreading/frizz-control
# https://www.naturallycurly.com/curlreading/curl-definition
# https://www.naturallycurly.com/curlreading/detangling
# https://www.naturallycurly.com/curly-hair/hair-growth
# https://www.naturallycurly.com/curlreading/breakage
# https://www.naturallycurly.com/curlreading/shrinkage
# https://www.naturallycurly.com/curlreading/hair-loss
# https://www.naturallycurly.com/curlreading/scalp-care
# https://www.naturallycurly.com/curlreading/heat-damage
# https://www.naturallycurly.com/curlreading/graying
# https://www.naturallycurly.com/curlreading/volume
# https://www.naturallycurly.com/curly-hair/hair-color
# https://www.naturallycurly.com/curlreading/haircuts
# https://www.naturallycurly.com/curlreading/hairstyles
# https://www.naturallycurly.com/curly-hair/transitioning
# https://www.naturallycurly.com/curlreading/straightening
# https://www.naturallycurly.com/curlreading/retexturizing
# https://www.naturallycurly.com/curlreading/curly-girl-method
# https://www.naturallycurly.com/curlreading/l-o-c-method
# https://www.naturallycurly.com/curlreading/second-day-hair
# https://www.naturallycurly.com/curlreading/cleansing
# https://www.naturallycurly.com/curlreading/conditioning
# https://www.naturallycurly.com/curly-hair/for-kids
# https://www.naturallycurly.com/curly-hair/for-men
# https://www.naturallycurly.com/salons
# https://www.naturallycurly.com/curlreading/celebrities
# https://www.naturallycurly.com/curlreading/beauty
# https://www.naturallycurly.com/curlreading/self-care
# https://www.naturallycurly.com/curlreading/culture
# https://www.naturallycurly.com/curlreading/business
# https://www.naturallycurly.com/videos
# https://www.naturallycurly.com/curlreading/product
# https://www.naturallycurly.com/curlreading/product
# https://www.naturallycurly.com/curlreading/ingredients
# https://www.naturallycurly.com/curlreading/latest-diy-products
# https://www.naturallycurly.com/editors-choice
# https://www.naturallycurly.com/curly-hair/awards
# https://www.naturallycurly.com/giveaways
# https://curltalk.naturallycurly.com/
# https://www.naturallycurly.com/stylenook
# https://curltalk.naturallycurly.com/
# https://trendsetter.naturallycurly.com/
# https://shop.naturallycurly.com/
# https://www.naturallycurly.com/contact
# https://www.essence.com
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# https://www.naturallycurly.com/texture-tales
# https://www.naturallycurly.com/leaders-in-curl
# https://www.naturallycurly.com/fresh-friday
# https://www.naturallycurly.com/curlreading/texture-on-the-runway
# javascript:void(0)
# /login
# https://www.facebook.com/naturallycurly/
# https://www.instagram.com/naturallycurly/
# https://www.youtube.com/channel/UCfWMjgi41FBXXkPLTaDluyQ
# https://twitter.com/naturallycurly
# https://curltalk.naturallycurly.com/
# https://curltalk.naturallycurly.com
# //curltalk.naturallycurly.com/categories/announcements
# https://curltalk.naturallycurly.com/categories/announcements
# /profile/ivandev
# /discussion/185493/rules-guidelines#latest
# /profile/ivandev
# /discussion/185493/rules-guidelines#latest
# //curltalk.naturallycurly.com/categories/announcements
# //curltalk.naturallycurly.com/categories/newbies-info
# https://curltalk.naturallycurly.com/categories/newbies-info
# /profile/Yj97
# /discussion/188655/my-hair-type-or-what-is-it-gonna-be-long#latest
# /profile/Yj97
# /discussion/188655/my-hair-type-or-what-is-it-gonna-be-long#latest
# //curltalk.naturallycurly.com/categories/newbies-info
# //curltalk.naturallycurly.com/categories/introductions
# https://curltalk.naturallycurly.com/categories/introductions
# /profile/LornaMc14
# /discussion/188649/hello-world#latest
# /profile/LornaMc14
# /discussion/188649/hello-world#latest
# //curltalk.naturallycurly.com/categories/introductions
# //curltalk.naturallycurly.com/categories/curlmart-news
# https://curltalk.naturallycurly.com/categories/curlmart-news
# /cdn-cgi/l/email-protection#87a7e4f2f4f3e8eae2f5f4e2f5f1eee4e2c7e9e6f3f2f5e6ebebfee4f2f5ebfea9e4e8ea
# /profile/System
# /discussion/180569/any-word-on-jessicurl-spiralicious#latest
# /profile/System
# /discussion/180569/any-word-on-jessicurl-spiralicious#latest
# //curltalk.naturallycurly.com/categories/curlmart-news
# //curltalk.naturallycurly.com/categories/feedback
# https://curltalk.naturallycurly.com/categories/feedback
# /profile/geminikiss
# /discussion/186021/list-of-issues-bugs-etc-from-the-last-few-months-that-i-want-to-revisit#latest
# /profile/geminikiss
# /discussion/186021/list-of-issues-bugs-etc-from-the-last-few-months-that-i-want-to-revisit#latest
# //curltalk.naturallycurly.com/categories/feedback
# //curltalk.naturallycurly.com/categories/c2
# https://curltalk.naturallycurly.com/categories/c2
# http://www.naturallycurly.com/topics/view/wavy-hair-type-2
# /profile/MelissaRoantreeLove
# /discussion/188610/twistedsista#latest
# /profile/MelissaRoantreeLove
# /discussion/188610/twistedsista#latest
# //curltalk.naturallycurly.com/categories/c2
# //curltalk.naturallycurly.com/categories/c3
# https://curltalk.naturallycurly.com/categories/c3
#
# http://www.naturallycurly.com/pages/hairtypes/type3
# /profile/Marvel7
# /discussion/19880/curl-activator-do-they-really-work#latest
# /profile/Marvel7
# /discussion/19880/curl-activator-do-they-really-work#latest
# //curltalk.naturallycurly.com/categories/c3
# //curltalk.naturallycurly.com/categories/c4
# https://curltalk.naturallycurly.com/categories/c4
# http://www.naturallycurly.com/pages/hairtypes/type4
# /profile/seyam22
# /discussion/140024/attention-the-official-type-4-whats-my-hair-type-thread#latest
# /profile/seyam22
# /discussion/140024/attention-the-official-type-4-whats-my-hair-type-thread#latest
# //curltalk.naturallycurly.com/categories/c4
# //curltalk.naturallycurly.com/categories/general-discussion-about-curly-hair
# https://curltalk.naturallycurly.com/categories/general-discussion-about-curly-hair
# /profile/bomega
# /discussion/187168/deva-clips-warning-and-is-there-a-secret-to-dealing-with-knots#latest
# /profile/bomega
# /discussion/187168/deva-clips-warning-and-is-there-a-secret-to-dealing-with-knots#latest
# //curltalk.naturallycurly.com/categories/general-discussion-about-curly-hair
# //curltalk.naturallycurly.com/categories/salon-stylist-chatter
# https://curltalk.naturallycurly.com/categories/salon-stylist-chatter
# http://www.naturallycurly.com/curlsalons
# /profile/katep
# /discussion/76806/what-should-i-tell-my-stylist#latest
# /profile/katep
# /discussion/76806/what-should-i-tell-my-stylist#latest
# //curltalk.naturallycurly.com/categories/salon-stylist-chatter
# //curltalk.naturallycurly.com/categories/transitioning
# https://curltalk.naturallycurly.com/categories/transitioning
# http://www.naturallycurly.com/topics/view/transitioning
# /profile/gloriamariana
# /discussion/186601/transitioning-acceptance#latest
# /profile/gloriamariana
# /discussion/186601/transitioning-acceptance#latest
# //curltalk.naturallycurly.com/categories/transitioning
# //curltalk.naturallycurly.com/categories/thin-thinning-hair
# https://curltalk.naturallycurly.com/categories/thin-thinning-hair
# /profile/curlypearl
# /discussion/188611/minoxidil#latest
# /profile/curlypearl
# /discussion/188611/minoxidil#latest
# //curltalk.naturallycurly.com/categories/thin-thinning-hair
# //curltalk.naturallycurly.com/categories/readers-product-reviews
# https://curltalk.naturallycurly.com/categories/readers-product-reviews
# http://www.naturallycurly.com/curlproducts
# /profile/l.grace
# /discussion/181703/alaffia-shampoo-and-conditioner#latest
# /profile/l.grace
# /discussion/181703/alaffia-shampoo-and-conditioner#latest
# //curltalk.naturallycurly.com/categories/readers-product-reviews
# //curltalk.naturallycurly.com/categories/hall-of-shame-discussion
# https://curltalk.naturallycurly.com/categories/hall-of-shame-discussion
# /profile/Anderson.Diamond93
# /discussion/30089/more-compliments-when-you-straighten-your-hair#latest
# /profile/Anderson.Diamond93
# /discussion/30089/more-compliments-when-you-straighten-your-hair#latest
# //curltalk.naturallycurly.com/categories/hall-of-shame-discussion
# //curltalk.naturallycurly.com/categories/hall-of-fame-discussion
# https://curltalk.naturallycurly.com/categories/hall-of-fame-discussion
# /profile/bobby
# /discussion/187198/mixed-reaction-giving-compliments-as-a-guy#latest
# /profile/bobby
# /discussion/187198/mixed-reaction-giving-compliments-as-a-guy#latest
# //curltalk.naturallycurly.com/categories/hall-of-fame-discussion
# //curltalk.naturallycurly.com/categories/curly-hairstyles
# https://curltalk.naturallycurly.com/categories/curly-hairstyles
# /profile/lhpopa
# /discussion/187275/how-do-i-hide-fix-this-disasterous-haircut#latest
# /profile/lhpopa
# /discussion/187275/how-do-i-hide-fix-this-disasterous-haircut#latest
# //curltalk.naturallycurly.com/categories/curly-hairstyles
# //curltalk.naturallycurly.com/categories/coloring-your-hair
# https://curltalk.naturallycurly.com/categories/coloring-your-hair
# http://www.naturallycurly.com/topics/view/hair_color
# /profile/elmaasheley147
# /discussion/188512/arctic-fox-dye#latest
# /profile/elmaasheley147
# /discussion/188512/arctic-fox-dye#latest
# //curltalk.naturallycurly.com/categories/coloring-your-hair
# //curltalk.naturallycurly.com/categories/trying-a-shampoo-free-method
# https://curltalk.naturallycurly.com/categories/trying-a-shampoo-free-method
# http://www.naturallycurly.com/topics/view/no-poo-cleansing
# /profile/tinksaysboo
# /discussion/178825/jessicurl-cleansing-cream-question#latest
# /profile/tinksaysboo
# /discussion/178825/jessicurl-cleansing-cream-question#latest
# //curltalk.naturallycurly.com/categories/trying-a-shampoo-free-method
# //curltalk.naturallycurly.com/categories/straightening-relaxing
# https://curltalk.naturallycurly.com/categories/straightening-relaxing
# http://www.naturallycurly.com/topics/view/straightening-keratin
# http://www.naturallycurly.com/topics/view/straightening-keratin
# /profile/Therese1
# /discussion/161039/how-to-keep-pixiecut-short-hair-straight-without-heat#latest
# /profile/Therese1
# /discussion/161039/how-to-keep-pixiecut-short-hair-straight-without-heat#latest
# //curltalk.naturallycurly.com/categories/straightening-relaxing
# //curltalk.naturallycurly.com/categories/keratin-services-and-treatment
# https://curltalk.naturallycurly.com/categories/keratin-services-and-treatment
# /profile/Surfacedup
# /discussion/113166/surface-hair-protein-smoothing-treatment-hate-it-help#latest
# /profile/Surfacedup
# /discussion/113166/surface-hair-protein-smoothing-treatment-hate-it-help#latest
# //curltalk.naturallycurly.com/categories/keratin-services-and-treatment
# //curltalk.naturallycurly.com/categories/health-related-hair-issues
# https://curltalk.naturallycurly.com/categories/health-related-hair-issues
# /profile/Cassieh
# /discussion/41785/curls-and-birth-control-pills#latest
# /profile/Cassieh
# /discussion/41785/curls-and-birth-control-pills#latest
# //curltalk.naturallycurly.com/categories/health-related-hair-issues
# //curltalk.naturallycurly.com/categories/recipes-for-hair-and-body
# https://curltalk.naturallycurly.com/categories/recipes-for-hair-and-body
# /profile/Natucurly
# /discussion/101013/guar-gum#latest
# /profile/Natucurly
# /discussion/101013/guar-gum#latest
# //curltalk.naturallycurly.com/categories/recipes-for-hair-and-body
# //curltalk.naturallycurly.com/categories/protein-sensitive
# https://curltalk.naturallycurly.com/categories/protein-sensitive
# /profile/Kirushi94
# /discussion/175656/coconut-oil-in-products#latest
# /profile/Kirushi94
# /discussion/175656/coconut-oil-in-products#latest
# //curltalk.naturallycurly.com/categories/protein-sensitive
# //curltalk.naturallycurly.com/categories/protein-craving
# https://curltalk.naturallycurly.com/categories/protein-craving
# /profile/rabar
# /discussion/186407/sulfates-in-maui-moisture#latest
# /profile/rabar
# /discussion/186407/sulfates-in-maui-moisture#latest
# //curltalk.naturallycurly.com/categories/protein-craving
# //curltalk.naturallycurly.com/categories/parents-of-curlies
# https://curltalk.naturallycurly.com/categories/parents-of-curlies
# http://www.naturallycurly.com/topics/view/kids
# /profile/Shirinheidari
# /discussion/146926/i-think-i-ruined-my-daughters-curly-hair-can-i-bring-her-curls-back#latest
# /profile/Shirinheidari
# /discussion/146926/i-think-i-ruined-my-daughters-curly-hair-can-i-bring-her-curls-back#latest
# //curltalk.naturallycurly.com/categories/parents-of-curlies
# //curltalk.naturallycurly.com/categories/curly-men
# https://curltalk.naturallycurly.com/categories/curly-men
# http://www.naturallycurly.com/topics/view/men
# /profile/Guide%2065
# /discussion/188632/how-to-manage-my-curls#latest
# /profile/Guide%2065
# /discussion/188632/how-to-manage-my-curls#latest
# //curltalk.naturallycurly.com/categories/curly-men
# //curltalk.naturallycurly.com/categories/curly-teens
# https://curltalk.naturallycurly.com/categories/curly-teens
# /profile/Lotsawaves
# /discussion/188060/is-this-website-hacked#latest
# /profile/Lotsawaves
# /discussion/188060/is-this-website-hacked#latest
# //curltalk.naturallycurly.com/categories/curly-teens
# //curltalk.naturallycurly.com/categories/over-40
# https://curltalk.naturallycurly.com/categories/over-40
# http://www.naturallycurly.com/topics/view/mature
# /profile/Alisond
# /discussion/98042/endometrial-ablation-mirena-anyone-done-this#latest
# /profile/Alisond
# /discussion/98042/endometrial-ablation-mirena-anyone-done-this#latest
# //curltalk.naturallycurly.com/categories/over-40
# //curltalk.naturallycurly.com/categories/going-gray
# https://curltalk.naturallycurly.com/categories/going-gray
# /profile/Soj
# /discussion/188366/do-anti-aging-ingredients-slow-down-the-going-gray#latest
# /profile/Soj
# /discussion/188366/do-anti-aging-ingredients-slow-down-the-going-gray#latest
# //curltalk.naturallycurly.com/categories/going-gray
# //curltalk.naturallycurly.com/categories/growing-out
# https://curltalk.naturallycurly.com/categories/growing-out
# /profile/Vicky-212
# /discussion/183420/my-hair-has-never-grown-past-my-shoulders#latest
# /profile/Vicky-212
# /discussion/183420/my-hair-has-never-grown-past-my-shoulders#latest
# //curltalk.naturallycurly.com/categories/growing-out
# //curltalk.naturallycurly.com/categories/all-natural-hair-care
# https://curltalk.naturallycurly.com/categories/all-natural-hair-care
# /profile/Kinky%20Queen
# /discussion/186035/has-anyone-tried-tm-hair-products#latest
# /profile/Kinky%20Queen
# /discussion/186035/has-anyone-tried-tm-hair-products#latest
# //curltalk.naturallycurly.com/categories/all-natural-hair-care
# //curltalk.naturallycurly.com/categories/celebs-hair
# https://curltalk.naturallycurly.com/categories/celebs-hair
# /profile/BrittanyM
# /discussion/188529/nathalie-emmanual-an-actual-hair-goddess#latest
# /profile/BrittanyM
# /discussion/188529/nathalie-emmanual-an-actual-hair-goddess#latest
# //curltalk.naturallycurly.com/categories/celebs-hair
# //curltalk.naturallycurly.com/categories/locs
# https://curltalk.naturallycurly.com/categories/locs
# /profile/Gretchen
# /discussion/149621/degrees-of-softness-and-breakage#latest
# /profile/Gretchen
# /discussion/149621/degrees-of-softness-and-breakage#latest
# //curltalk.naturallycurly.com/categories/locs
# //curltalk.naturallycurly.com/categories/high-porosity
# https://curltalk.naturallycurly.com/categories/high-porosity
# http://www.naturallycurly.com/curlreading/curl-products/curlchemist-porosity-and-curly-hair
# /profile/KerrBearrxo
# /discussion/179580/day-2-hair-dries-out-quickly-once-refreshed#latest
# /profile/KerrBearrxo
# /discussion/179580/day-2-hair-dries-out-quickly-once-refreshed#latest
# //curltalk.naturallycurly.com/categories/high-porosity
# //curltalk.naturallycurly.com/categories/normal-porosity
# https://curltalk.naturallycurly.com/categories/normal-porosity
# http://www.naturallycurly.com/curlreading/curl-products/curlchemist-porosity-and-curly-hair
# /profile/Therese1
# /discussion/162496/my-hair-is-high-and-low-porosity-or-normal-help#latest
# /profile/Therese1
# /discussion/162496/my-hair-is-high-and-low-porosity-or-normal-help#latest
# //curltalk.naturallycurly.com/categories/normal-porosity
# //curltalk.naturallycurly.com/categories/low-porosity
# https://curltalk.naturallycurly.com/categories/low-porosity
# http://www.naturallycurly.com/curlreading/curl-products/curlchemist-porosity-and-curly-hair
# /profile/coffeespoon
# /discussion/187988/help-for-undefined-low-porosity-hair#latest
# /profile/coffeespoon
# /discussion/187988/help-for-undefined-low-porosity-hair#latest
# //curltalk.naturallycurly.com/categories/low-porosity
# //curltalk.naturallycurly.com/categories/fine-width-
# https://curltalk.naturallycurly.com/categories/fine-width-
# https://www.naturallycurly.com/texture-typing/hair-width
# /profile/SuperCUrlsToday
# /discussion/188575/fine-hair-on-a-budget#latest
# /profile/SuperCUrlsToday
# /discussion/188575/fine-hair-on-a-budget#latest
# //curltalk.naturallycurly.com/categories/fine-width-
# //curltalk.naturallycurly.com/categories/medium-width-hair
# https://curltalk.naturallycurly.com/categories/medium-width-hair
# https://www.naturallycurly.com/texture-typing/hair-width
# //curltalk.naturallycurly.com/categories/coarse
# https://curltalk.naturallycurly.com/categories/coarse
# https://www.naturallycurly.com/texture-typing/hair-width
# /profile/valen_tina
# /discussion/185885/what-conditioner-actually-worked-to-make-your-coarse-hair-soft#latest
# /profile/valen_tina
# /discussion/185885/what-conditioner-actually-worked-to-make-your-coarse-hair-soft#latest
# //curltalk.naturallycurly.com/categories/coarse
# //curltalk.naturallycurly.com/categories/swap-board
# https://curltalk.naturallycurly.com/categories/swap-board
# /profile/fefferknits
# /discussion/188634/kccc-mielle-obia-naturals-sheamoisture-more#latest
# /profile/fefferknits
# /discussion/188634/kccc-mielle-obia-naturals-sheamoisture-more#latest
# //curltalk.naturallycurly.com/categories/swap-board
# //curltalk.naturallycurly.com/categories/swap-board-for-canadians
# https://curltalk.naturallycurly.com/categories/swap-board-for-canadians
# /profile/Jol17
# /discussion/51606/curl-friendly-hair-salon-or-stylist-in-london-ontario#latest
# /profile/Jol17
# /discussion/51606/curl-friendly-hair-salon-or-stylist-in-london-ontario#latest
# //curltalk.naturallycurly.com/categories/swap-board-for-canadians
# //curltalk.naturallycurly.com/categories/swap-board-for-eurocurlies
# https://curltalk.naturallycurly.com/categories/swap-board-for-eurocurlies
# /profile/EmilieFrance
# /discussion/187192/is-there-any-french-curlies-around-here#latest
# /profile/EmilieFrance
# /discussion/187192/is-there-any-french-curlies-around-here#latest
# //curltalk.naturallycurly.com/categories/swap-board-for-eurocurlies
# //curltalk.naturallycurly.com/categories/aussie-swap-board
# https://curltalk.naturallycurly.com/categories/aussie-swap-board
# /profile/MrsGerkin
# /discussion/181361/curly-dry-hairdressers-cutting-wollongong-illawarra#latest
# /profile/MrsGerkin
# /discussion/181361/curly-dry-hairdressers-cutting-wollongong-illawarra#latest
# //curltalk.naturallycurly.com/categories/aussie-swap-board
# //curltalk.naturallycurly.com/categories/other-beauty-products-swap-board
# https://curltalk.naturallycurly.com/categories/other-beauty-products-swap-board
# /profile/curlyknw
# /discussion/186380/i-need-biolalges-curl-defining-creme#latest
# /profile/curlyknw
# /discussion/186380/i-need-biolalges-curl-defining-creme#latest
# //curltalk.naturallycurly.com/categories/other-beauty-products-swap-board
# //curltalk.naturallycurly.com/categories/book-swap-board
# https://curltalk.naturallycurly.com/categories/book-swap-board
# /profile/jeepcurlygurl
# /discussion/186234/the-curl-revolution-book-new-sold#latest
# /profile/jeepcurlygurl
# /discussion/186234/the-curl-revolution-book-new-sold#latest
# //curltalk.naturallycurly.com/categories/book-swap-board
# //curltalk.naturallycurly.com/categories/non-hair-discussion
# https://curltalk.naturallycurly.com/categories/non-hair-discussion
# /profile/Lotsawaves
# /discussion/188627/i-think-naturallycurly-com-may-have-had-a-data-leak#latest
# /profile/Lotsawaves
# /discussion/188627/i-think-naturallycurly-com-may-have-had-a-data-leak#latest
# //curltalk.naturallycurly.com/categories/non-hair-discussion
# //curltalk.naturallycurly.com/categories/recipes-stuff-to-eat
# https://curltalk.naturallycurly.com/categories/recipes-stuff-to-eat
# /profile/charliebrown1988
# /discussion/173539/what-is-the-best-thing-you-have-ever-eaten#latest
# /profile/charliebrown1988
# /discussion/173539/what-is-the-best-thing-you-have-ever-eaten#latest
# //curltalk.naturallycurly.com/categories/recipes-stuff-to-eat
# //curltalk.naturallycurly.com/categories/curly-fitness
# https://curltalk.naturallycurly.com/categories/curly-fitness
# /profile/dangerflakes
# /discussion/188467/at-home-workout-ideas#latest
# /profile/dangerflakes
# /discussion/188467/at-home-workout-ideas#latest
# //curltalk.naturallycurly.com/categories/curly-fitness
# //curltalk.naturallycurly.com/categories/curl-gatherings
# https://curltalk.naturallycurly.com/categories/curl-gatherings
# /profile/bobby
# /discussion/180524/bay-area-east-bay-curlistas#latest
# /profile/bobby
# /discussion/180524/bay-area-east-bay-curlistas#latest
# //curltalk.naturallycurly.com/categories/curl-gatherings
# //curltalk.naturallycurly.com/categories/makeup-skin-care
# https://curltalk.naturallycurly.com/categories/makeup-skin-care
# http://www.naturallycurly.com/topics/view/makeup
# http://www.naturallycurly.com/topics/view/skincare-health-beauty
# /profile/Spiralli
# /discussion/134633/help-mask-burned-my-face#latest
# /profile/Spiralli
# /discussion/134633/help-mask-burned-my-face#latest
# //curltalk.naturallycurly.com/categories/makeup-skin-care
# //curltalk.naturallycurly.com/categories/the-curlybook-club
# https://curltalk.naturallycurly.com/categories/the-curlybook-club
# /profile/hmr1016
# /discussion/187655/supporting-women-authors#latest
# /profile/hmr1016
# /discussion/187655/supporting-women-authors#latest
# //curltalk.naturallycurly.com/categories/the-curlybook-club
# //curltalk.naturallycurly.com/categories/politics
# https://curltalk.naturallycurly.com/categories/politics
# /profile/CatitudeBoo
# /discussion/116285/are-you-a-feminist#latest
# /profile/CatitudeBoo
# /discussion/116285/are-you-a-feminist#latest
# //curltalk.naturallycurly.com/categories/politics
# //curltalk.naturallycurly.com/categories/pregnancy-parenting
# https://curltalk.naturallycurly.com/categories/pregnancy-parenting
# /profile/leepalmer
# /discussion/115833/disinfecting-stuffed-animals#latest
# /profile/leepalmer
# /discussion/115833/disinfecting-stuffed-animals#latest
# //curltalk.naturallycurly.com/categories/pregnancy-parenting
# /entry/signin?Target=categories
# /entry/register?Target=categories
# /entry/signin?Target=categories
# /entry/register?Target=categories
# /post/discussion
# /post/discussion
# /post/question
# /categories#
# /categories
# /discussions
# /activity
# /bestof/everything
# /discussions/unanswered
# /discussions/tagged/curly-hair-solutions
# /discussions/tagged/how-to
# /discussions/tagged/using-curltalk-how-tos
# /discussions/tagged/search
# /discussions/tagged/shop-naturallycurly
# /discussions/tagged/oil
# /discussions/tagged/test
# /discussions/tagged/sale
# /discussions/tagged/phyto-specific
# /discussions/tagged/texture-on-the-runway
# /discussions/tagged/lip-balm
# /discussions/tagged/totr
# /about-us
# /contact
# /privacy-policy
# /terms-of-use/
# /community-policy/
# https://www.facebook.com/naturallycurly/
# https://www.pinterest.com/naturallycurly/
# https://twitter.com/naturallycurly
# https://www.instagram.com/naturallycurly/
# https://www.youtube.com/channel/UCfWMjgi41FBXXkPLTaDluyQ
# /cdn-cgi/l/email-protection#2c6f434242494f586c424d58595e4d4040554f595e4055024f4341
# /my-account
# /user/view/username/
# /logout

# %%
link_list_forum_top = []
for link in soup2.find_all('a'):
    link_list_forum_top.append(link.get('href'))
categories = [s for s in link_list_forum_top if (("categories" in s) and ('https' in s))]
categories
# Out:
# ['https://curltalk.naturallycurly.com/categories/announcements',
#  'https://curltalk.naturallycurly.com/categories/newbies-info',
#  'https://curltalk.naturallycurly.com/categories/introductions',
#  'https://curltalk.naturallycurly.com/categories/curlmart-news',
#  'https://curltalk.naturallycurly.com/categories/feedback',
#  'https://curltalk.naturallycurly.com/categories/c2',
#  'https://curltalk.naturallycurly.com/categories/c3',
#  'https://curltalk.naturallycurly.com/categories/c4',
#  'https://curltalk.naturallycurly.com/categories/general-discussion-about-curly-hair',
#  'https://curltalk.naturallycurly.com/categories/salon-stylist-chatter',
#  'https://curltalk.naturallycurly.com/categories/transitioning',
#  'https://curltalk.naturallycurly.com/categories/thin-thinning-hair',
#  'https://curltalk.naturallycurly.com/categories/readers-product-reviews',
#  'https://curltalk.naturallycurly.com/categories/hall-of-shame-discussion',
#  'https://curltalk.naturallycurly.com/categories/hall-of-fame-discussion',
#  'https://curltalk.naturallycurly.com/categories/curly-hairstyles',
#  'https://curltalk.naturallycurly.com/categories/coloring-your-hair',
#  'https://curltalk.naturallycurly.com/categories/trying-a-shampoo-free-method',
#  'https://curltalk.naturallycurly.com/categories/straightening-relaxing',
#  'https://curltalk.naturallycurly.com/categories/keratin-services-and-treatment',
#  'https://curltalk.naturallycurly.com/categories/health-related-hair-issues',
#  'https://curltalk.naturallycurly.com/categories/recipes-for-hair-and-body',
#  'https://curltalk.naturallycurly.com/categories/protein-sensitive',
#  'https://curltalk.naturallycurly.com/categories/protein-craving',
#  'https://curltalk.naturallycurly.com/categories/parents-of-curlies',
#  'https://curltalk.naturallycurly.com/categories/curly-men',
#  'https://curltalk.naturallycurly.com/categories/curly-teens',
#  'https://curltalk.naturallycurly.com/categories/over-40',
#  'https://curltalk.naturallycurly.com/categories/going-gray',
#  'https://curltalk.naturallycurly.com/categories/growing-out',
#  'https://curltalk.naturallycurly.com/categories/all-natural-hair-care',
#  'https://curltalk.naturallycurly.com/categories/celebs-hair',
#  'https://curltalk.naturallycurly.com/categories/locs',
#  'https://curltalk.naturallycurly.com/categories/high-porosity',
#  'https://curltalk.naturallycurly.com/categories/normal-porosity',
#  'https://curltalk.naturallycurly.com/categories/low-porosity',
#  'https://curltalk.naturallycurly.com/categories/fine-width-',
#  'https://curltalk.naturallycurly.com/categories/medium-width-hair',
#  'https://curltalk.naturallycurly.com/categories/coarse',
#  'https://curltalk.naturallycurly.com/categories/swap-board',
#  'https://curltalk.naturallycurly.com/categories/swap-board-for-canadians',
#  'https://curltalk.naturallycurly.com/categories/swap-board-for-eurocurlies',
#  'https://curltalk.naturallycurly.com/categories/aussie-swap-board',
#  'https://curltalk.naturallycurly.com/categories/other-beauty-products-swap-board',
#  'https://curltalk.naturallycurly.com/categories/book-swap-board',
#  'https://curltalk.naturallycurly.com/categories/non-hair-discussion',
#  'https://curltalk.naturallycurly.com/categories/recipes-stuff-to-eat',
#  'https://curltalk.naturallycurly.com/categories/curly-fitness',
#  'https://curltalk.naturallycurly.com/categories/curl-gatherings',
#  'https://curltalk.naturallycurly.com/categories/makeup-skin-care',
#  'https://curltalk.naturallycurly.com/categories/the-curlybook-club',
#  'https://curltalk.naturallycurly.com/categories/politics',
#  'https://curltalk.naturallycurly.com/categories/pregnancy-parenting']

# %% [markdown]
# ### Look at the Topics and try to find a way to loop through all the different discusions on a page and then extrapolate that to each page of the discussions to u

# %%
url = categories[0]
user_agent =  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
html_page = requests.get(url, headers = {'User-Agent': user_agent} ) #Make a get request to retrieve the page
soup3 = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing
soup3.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="r8espbQAjIbeGDwID6nId4gRNQr3p6uaawtkpKQI" name="csrf-token"/>
# <meta content="index, follow" name="robots"/>
# <meta content="244330805725130" name="fb:app_id" property="fb:app_id"/>
# <meta content="44517541327" name="fb:pages" property="fb:pages"/>
# <meta content="e889ec2da676423098e4ea8786e4178d" name="p:domain_verify" property="p:domain_verify"/>
# <title>Announcements — CurlTalk</title>
# <link href="https://curltalk.naturallycurly.com/categories/announcements/feed.rss" rel="alternate" title="Announcements — CurlTalk" type="application/rss+xml"/>
# <link href="https://curltalk.naturallycurly.com/categories/announcements/p2" rel="next"/>
# <link href="/applications/dashboard/design/style.css?v=3.0.5d38a13c" media="all" rel="stylesheet"/>
# <link href="https://curltalk.naturallycurly.com/applications/dashboard/design/style-compat.css?v=3.1-2019.010.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/Signatures/design/signature.css?v=1.6.1.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/Reactions/design/reactions.css?v=1.4.6.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/Polls/design/polls.css?v=1.2.4.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/IndexPhotos/design/indexphotos.css?v=1.2.2.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/Warnings2/design/warnings.css?v=2.5.1.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/badges/design/badges.css?v=1.6.1.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/AdvancedSearch/design/advanced-search.css?v=1.1.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/resources/design/vanillicon.css?v=3.1-2019.010.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/editor/design/editor.css?v=1.8.1.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/applications/vanilla/design/tag.css?v=3.0.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/plugins/Online/design/online.css?v=1.7.1.5d38a13c" media="all" rel="stylesheet"/>
# <link href="/applications/vanilla/design/spoilers.css?v=3.0.5d38a13c" media="all" rel="stylesheet"/>
# <link href="https://us.v-cdn.net/6030387/uploads/favicon_742e5b705682632797ea27349bba3110.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://us.v-cdn.net/6030387/uploads/favicon-152-a80f4638f8f309f4db688f9db91b3197.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://curltalk.naturallycurly.com/categories/announcements" rel="canonical"/>
# <meta content="#6b009d" name="theme-color">
# <meta content="CurlTalk" property="og:site_name">
# <meta content="Announcements" name="twitter:title" property="og:title">
# <meta content="https://curltalk.naturallycurly.com/categories/announcements" property="og:url">
# <meta content="Announcements from the curlyheads at NaturallyCurly.com" name="description" property="og:description">
# <meta content="https://us.v-cdn.net/6030387/uploads/876f0f9e8a4f2ec070ab20ffc5190f28.png" property="og:image">
# <script>gdn=window.gdn||{};gdn.meta={"emoji":{"assetPath":"https:\/\/curltalk.naturallycurly.com\/resources\/emoji","format":"<img class=\"emoji\" src=\"%1$s\" title=\"%2$s\" alt=\"%2$s\" height=\"20\" \/>","emoji":{"smile":"smile.png","smiley":"smiley.png","wink":"wink.png","blush":"blush.png","neutral":"neutral.png","relaxed":"relaxed.png","grin":"grin.png","joy":"joy.png","sweat_smile":"sweat_smile.png","lol":"lol.png","innocent":"innocent.png","naughty":"naughty.png","yum":"yum.png","relieved":"relieved.png","love":"love.png","sunglasses":"sunglasses.png","smirk":"smirk.png","expressionless":"expressionless.png","unamused":"unamused.png","sweat":"sweat.png","pensive":"pensive.png","confused":"confused.png","confounded":"confounded.png","kissing":"kissing.png","kissing_heart":"kissing_heart.png","kissing_smiling_eyes":"kissing_smiling_eyes.png","kissing_closed_eyes":"kissing_closed_eyes.png","tongue":"tongue.png","disappointed":"disappointed.png","worried":"worried.png","angry":"angry.png","rage":"rage.png","cry":"cry.png","persevere":"persevere.png","triumph":"triumph.png","frowning":"frowning.png","anguished":"anguished.png","fearful":"fearful.png","weary":"weary.png","sleepy":"sleepy.png","tired_face":"tired_face.png","grimace":"grimace.png","bawling":"bawling.png","open_mouth":"open_mouth.png","hushed":"hushed.png","cold_sweat":"cold_sweat.png","scream":"scream.png","astonished":"astonished.png","flushed":"flushed.png","sleeping":"sleeping.png","dizzy":"dizzy.png","no_mouth":"no_mouth.png","mask":"mask.png","star":"star.png","cookie":"cookie.png","warning":"warning.png","mrgreen":"mrgreen.png","heart":"heart.png","heartbreak":"heartbreak.png","kiss":"kiss.png","+1":"+1.png","-1":"-1.png","grey_question":"grey_question.png","trollface":"trollface.png","error":"grey_question.png"}},"ShowUserReactions":"popup","keenio.projectID":"5a25a19dc9e77c000109a241","keenio.writeKey":"A7221599A669EDB1FA887BC8DF411C1A9B02D6998FC4D41F0595CF02DD7AF9396B8ECB6FAC6B93C9E7E9D8C113730163D5B88840D400C4D2540F8C987E867426FEBC8A094EB547126A641845F33709734F52DBE4737A773752D9BCD462B80792","vaCookieName":"vf_naturallycurly_SBK6E-vA","eventData":{"ip":"0.0.0.0","method":"GET","site":{"accountID":60186499,"name":"naturallycurly.vanillacommunities.com","siteID":6030387},"url":"https:\/\/curltalk.naturallycurly.com\/categories\/announcements","_country":"US","user":{"dateFirstVisit":null,"name":"@guest","roleType":"guest","userID":0},"userAgent":"Mozilla\/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit\/537.36 (KHTML, like Gecko) Chrome\/75.0.3770.100 Safari\/537.36","keen":{"addons":[{"name":"keen:ip_to_geo","input":{"ip":"ip"},"output":"ipGeo"},{"name":"keen:url_parser","input":{"url":"url"},"output":"urlParsed"},{"name":"keen:ua_parser","input":{"ua_string":"userAgent"},"output":"userAgentParsed"},{"name":"keen:referrer_parser","input":{"referrer_url":"referrer","page_url":"url"},"output":"referrerParsed"}]},"discussion":{"discussionID":0}},"viewEventType":"page_view","TagHint":"Start to type...","TagSearching":"Searching...","TagNoResults":"No results","editorVersion":"1.8.1","editorPluginAssets":"\/plugins\/editor","fileUpload-remove":"Remove file","fileUpload-reattach":"Click to re-attach","fileUpload-inserted":"Inserted","fileUpload-insertedTooltip":"This image has been inserted into the body of text.","wysiwygHelpText":"You are using <a href=\"https:\/\/en.wikipedia.org\/wiki\/WYSIWYG\" target=\"_new\">WYSIWYG<\/a> in your post.","bbcodeHelpText":"You can use <a href=\"http:\/\/en.wikipedia.org\/wiki\/BBCode\" target=\"_new\">BBCode<\/a> in your post.","htmlHelpText":"You can use <a href=\"http:\/\/htmlguide.drgrog.com\/cheatsheet.php\" target=\"_new\">Simple HTML<\/a> in your post.","markdownHelpText":"You can use <a href=\"http:\/\/en.wikipedia.org\/wiki\/Markdown\" target=\"_new\">Markdown<\/a> in your post.","textHelpText":"You are using plain text in your post.","editorWysiwygCSS":"\/plugins\/editor\/design\/wysiwyg.css","canUpload":fa ...
# gdn.permissions={"permissions":{"activity.view":true,"profiles.view":true,"discussions.view":true,"badges.view":true,"discussions.add":[-1,80],"comments.add":[-1,80]},"bans":[],"isAdmin":false};
# window.__ACTIONS__=[];
# </script>
# <script src="/js/library/jquery.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/js/library/jquery.form.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/js/library/jquery.popup.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/js/library/jquery.popin.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/js/library/jquery.gardenhandleajaxform.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/js/library/jquery.atwho.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/js/global.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/js/flyouts.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/applications/vanilla/js/discussions.js?v=3.0.5d38a13c"></script>
# <script src="/js/library/jquery.tokeninput.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/plugins/AuthorSelector/js/authorselector.js?v=1.3.5d38a13c"></script>
# <script src="/plugins/vanillaanalytics/js/vendors/js.cookie.js?v=1.2.5d38a13c"></script>
# <script src="/plugins/vanillaanalytics/js/vendors/keen.min.js?v=1.2.5d38a13c"></script>
# <script src="/plugins/vanillaanalytics/js/keenio.min.js?v=1.2.5d38a13c"></script>
# <script src="/js/library/jquery-ui.min.js?v=3.1-2019.010.5d38a13c"></script>
# <script src="/plugins/AdvancedSearch/js/advanced-search.js?v=1.1.5d38a13c"></script>
# <script src="/plugins/editor/js/editor.js?v=1.8.1.5d38a13c"></script>
# <script src="/plugins/editor/js/jquery.ui.widget.js?v=1.8.1.5d38a13c"></script>
# <script src="/plugins/editor/js/jquery.iframe-transport.js?v=1.8.1.5d38a13c"></script>
# <script src="/plugins/editor/js/jquery.fileupload.js?v=1.8.1.5d38a13c"></script>
# <script src="/applications/vanilla/js/spoilers.js?v=3.0.5d38a13c"></script>
# <script src="/applications/vanilla/js/tagging.js?v=3.0.5d38a13c"></script>
# <script>var supportsAllFeatures = window.Promise && window.fetch && window.Symbol&& window.CustomEvent && Element.prototype.remove && Element.prototype.closest&& window.NodeList && NodeList.prototype.forEach;if (!supportsAllFeatures) {var head = document.getElementsByTagName('head')[0];var script = document.createElement('script');script.src = 'https://curltalk.naturallycurly.com/dist/polyfills.min.js?h=5d38a13c';head.appendChild(script);} else {  }</script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/api/v2/locales/en/translations.js?h=5d38a13c"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/runtime.min.js?h=5d38a13c"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/vendors.min.js?h=5d38a13c"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/shared.min.js?h=5d38a13c"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/addons/rich-editor.min.js?h=5d38a13c"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/addons/dashboard.min.js?h=5d38a13c"></script>
# <script defer="defer" src="https://curltalk.naturallycurly.com/dist/forum/bootstrap.min.js?h=5d38a13c"></script>
# <link href="https://www.naturallycurly.com/css/app.css?id=75d11e028136b20c36dc" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/system-alerts/css/index.css?id=bee82e70ef295e22bb71" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/css/index.css?id=29ad982865bba35342db" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/with-images/css/index.css?id=08e5dae4897d7fa929ae" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/with-columns/css/index.css?id=181b8cf4f3255c2b70cf" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/detailed-list/css/index.css?id=40faf08d1053cbf0d5cb" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/components/dropdown-menu/css/index.css?id=40faf08d1053cbf0d5cb" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/navbar-items/css/index.css?id=bc55415dd77e8f09f1af" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/login/css/index.css?id=eaba96cc36cf17352583" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/search-bar/css/index.css?id=fcc7b359def1f7f41bac" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/shopping-cart/css/index.css?id=13aa1754c79dba962603" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/subscribe/css/index.css?id=d150abad71a0439f72be" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/features/css/index.css?id=d4b14d61b68b70ab7d75" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/css/index.css?id=862ceb4808d65390dd0c" rel="stylesheet"/>
# <link href="https://www.naturallycurly.com/assets/views/page-layouts/vanilla-forums-default-plain/css/index.css?id=e627191e9a199029bc1b" rel="stylesheet"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-477881-3"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-477881-3', {
#                 'optimize_id': 'GTM-P86LPBZ',
#         'page_title':'',
#         'page_path':''
#     });
#
#
#
#     </script>
# <script> !function(f,b,e,v,n,t,s) {if(f.fbq)return;n=f.fbq=function(){n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}; if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0'; n.queue=[];t=b.createElement(e);t.async=!0; t.src=v;s=b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t,s)}(window,document,'script', 'https://connect.facebook.net/en_US/fbevents.js'); fbq('init', '369905576513231'); fbq('track', 'PageView'); </script>
# <script type="text/javascript">
# (function(d,s,i,r) {
#   if (d.getElementById(i)){return;}
#   var n=d.createElement(s),e=d.getElementsByTagName(s)[0];
#   n.id=i;n.src='//js.hs-analytics.net/analytics/'+(Math.ceil(new Date()/r)*r)+'/2272072.js';
#   e.parentNode.insertBefore(n, e);
# })(document,"script","hs-analytics",300000);
# </script>
# <script async="async" src="//cdn.adsafeprotected.com/iasPET.1.js"></script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().setTargeting('path', 'vanilla-forums');
#                 googletag.pubads().setTargeting('URL', 'vanilla-forums/master-template');
#                 googletag.pubads().setTargeting('env', 'www');
#     });
#
#     var dfpAdSlots = {};
#     var initDfpAdsFunctions = {};
# </script>
# <!--[if lte IE 8]>
# <script charset="utf-8" type="text/javascript" src="//js.hsforms.net/forms/v2-legacy.js"></script>
# <![endif]-->
# <script charset="utf-8" src="//js.hsforms.net/forms/v2.js" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/js/DianaApi.js" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/js/DianaApiClient.js" type="text/javascript"></script>
# </meta></meta></meta></meta></meta></meta></head>
# <body class="Vanilla Categories isDesktop index Discussions Category-announcements Section-Category-announcements Section-DiscussionList vanilla-forums-default-plain sticky-header-body" id="vanilla_categories_index">
# <div class="alerts-container">
# </div>
# <div class="alert-template">
# <div aria-atomic="true" aria-live="assertive" class="system-alert card" role="alert">
# <div class="card-body">
# <div class="alert-header-container card-title">
# <div class="alert-title-container">
# <i class="fas fa-bell alert-icon-success mr-2"></i>
# <i class="fas fa-bell alert-icon-error mr-2"></i>
# <strong class="mr-auto alert-title"></strong>
# <small class="text-muted alert-title-date"></small>
# </div>
# <div aria-label="Close" class="ml-2 mb-1 alert-close-btn">
# <i class="fas fa-times"></i>
# </div>
# </div>
# <div class="alert-body card-text">
# </div>
# </div>
# </div></div>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.10&appId=244330805725130";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <div class="navbar-custom">
# <div class="container-fluid banner-top nct-banner">
# <div class="row justify-content-center leaderboard-container">
# <div class="google-dfp-adspace" data-ad-rendered-sizes="[[1, 1], [300, 250], [970, 250], [300, 600], [320, 50], [970, 90], [728, 90]]" data-ad-sizes="responsive-full-page-banner-top-ad" data-ad-slot="googletag" data-ad-url="/21698916284/naturallycurly/topics" id="NC_T"></div>
# </div>
# </div>
# <div class="fixed-menu">
# <div class="row mx-0 background-content">
# <nav class="navbar navbar-expand-lg collapse-sidebar">
# <div class="navbar-top-part row">
# <div class="col-2">
# <div class="navbar-left-container">
# <a class="navbar-logo-container" href="https://www.naturallycurly.com">
# <img class="nc-logo" src="https://www.naturallycurly.com/img/naturallycurly.png"/>
# </a>
# <button class="main-menu-button-mobile navbar-toggler">
# <i class="fa fa-bars">
# <mark class="number-notifications"></mark>
# </i>
# </button>
# </div>
# </div>
# <div class="col-8 col-sm-9 col-xl-8">
# <div class="navbar-center-container">
# <a class="navbar-logo-container" href="https://www.naturallycurly.com">
# <img class="nc-logo" src="https://www.naturallycurly.com/img/naturallycurly.png"/>
# </a>
# <div class="navbar-items-container">
# <ul class="navbar-nav">
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/quiz" id="navbarDropdown0">
# TEXTURE
# </a>
# <div aria-labelledby="menu-texture" class="dropdown-menu nc-dropdown-menu sidebar-menu with-images">
# <div class="dropdown-menu-submenu nc-dropdown-menu-submenu with-images-submenu">
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <span class="dropdown-title nc-dropdown-title">WAVY (2a-2c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a loose “S” very easily straightened</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2a-720x864.jpg">
# </img></div>
# <span class="image-label">2a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2b-720x864.jpg">
# </img></div>
# <span class="image-label">2b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2c-720x864.jpg"/>
# </div>
# <span class="image-label">2c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <span class="dropdown-title nc-dropdown-title">CURLY (3a-3c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a definite “S” shaped like a corkscrew</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3a-720x864.jpg"/>
# </div>
# <span class="image-label">3a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3b-720x864.jpg"/>
# </div>
# <span class="image-label">3b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3c-720x864.jpg"/>
# </div>
# <span class="image-label">3c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <span class="dropdown-title nc-dropdown-title">COILY (4a-4c)</span>
# <span class="dropdown-description nc-dropdown-description">Very tight curl when stretched creates an “S”</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4a-720x864.jpg"/>
# </div>
# <span class="image-label">4a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4b-720x864.jpg"/>
# </div>
# <span class="image-label">4b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4c-720x864.jpg"/>
# </div>
# <span class="image-label">4c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <span class="dropdown-title nc-dropdown-title">LOCS</span>
# <span class="dropdown-description nc-dropdown-description">Hair intentionally matted to form "ropes"</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/ljbRc5dYtPNc1537231421.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/quiz">
# <span class="dropdown-title nc-dropdown-title">QUIZ</span>
# <span class="dropdown-description nc-dropdown-description">Take our quiz to learn your curl pattern</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/quiz">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/Zosdxmktbe7i1537230313.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/curlreading" id="navbarDropdown1">
# <div class="columns-menu">TOPICS</div>
# </a>
# <div class="dropdown-menu nc-dropdown-menu large-menu with-columns">
# <div class="nc-dropdown-menu-submenu">
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CONCERNS</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/dryness" id="dryness">Dryness</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/frizz-control" id="frizz">Frizz</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curl-definition" id="curl-definition">Curl Definition</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/detangling" id="detangling">Detangling</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-growth" id="hair-growth">Hair Growth</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/breakage" id="hair-breakage">Hair Breakage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/shrinkage" id="shrinkage">Shrinkage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hair-loss" id="hair-loss">Hair Loss</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/scalp-care" id="scalp-care">Scalp Care</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/heat-damage" id="heat-damage">Heat Damage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/graying" id="graying">Graying</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/volume" id="volume">Volume</a></li>
# </ul>
# </div>
# </div>
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CURL CARE</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-color" id="hair-color">Hair Color</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/haircuts" id="haircuts">Haircuts</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hairstyles" id="hairstyles">Hairstyles</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/transitioning" id="transitioning">Transitioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/straightening" id="straightening">Straightening</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/retexturizing" id="retexturizing">Retexturizing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curly-girl-method" id="curly-girl-method">Curly Girl Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/l-o-c-method" id="loc-method">LOC Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/second-day-hair" id="2nd-day-hair">2nd Day Hair</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/cleansing" id="cleansing">Cleansing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/conditioning" id="conditioning">Conditioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/for-kids" id="kids">Kids</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/for-men" id="men">Men</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/salons" id="salon-finder">Salon Finder</a></li>
# </ul>
# </div>
# </div>
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">LIFESTYLE</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/celebrities" id="celebrities">Celebrities</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/beauty" id="beauty">Beauty</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/self-care" id="self-care">Self-Care</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/culture" id="culture">Culture</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/business" id="business">Business</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.naturallycurly.com/videos" id="navbarDropdown2">
# VIDEOS
# </a>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/curlreading/product" id="navbarDropdown3">
# PRODUCTS
# </a>
# <div aria-labelledby="navbarDropdown3" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curlreading/product">
# <span class="dropdown-title nc-dropdown-title">TOP PRODUCTS</span>
# <span class="dropdown-description nc-dropdown-description">Guides and resources for easy product selection</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curlreading/ingredients">
# <span class="dropdown-title nc-dropdown-title">INGREDIENTS</span>
# <span class="dropdown-description nc-dropdown-description">Learn how to read your hair product labels</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curlreading/latest-diy-products">
# <span class="dropdown-title nc-dropdown-title">DIY PRODUCTS</span>
# <span class="dropdown-description nc-dropdown-description">Easy-to-make recipes for all your haircare needs</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/editors-choice">
# <span class="dropdown-title nc-dropdown-title">EDITORS' CHOICE</span>
# <span class="dropdown-description nc-dropdown-description">Our editors share their top hair and skincare products</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/curly-hair/awards">
# <span class="dropdown-title nc-dropdown-title">BEST OF THE BEST</span>
# <span class="dropdown-description nc-dropdown-description">Community member favorites make up this coveted list</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/giveaways">
# <span class="dropdown-title nc-dropdown-title">GIVEAWAYS</span>
# <span class="dropdown-description nc-dropdown-description">Enter to win products we all love</span>
# </a>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://curltalk.naturallycurly.com/" id="navbarDropdown4" target="_blank">
# COMMUNITY
# </a>
# <div aria-labelledby="navbarDropdown4" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="https://www.naturallycurly.com/stylenook">
# <span class="dropdown-title nc-dropdown-title">STYLENOOK</span>
# <span class="dropdown-description nc-dropdown-description">Share your style and browse the style of others</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://curltalk.naturallycurly.com/" target="_blank">
# <span class="dropdown-title nc-dropdown-title">CURLTALK</span>
# <span class="dropdown-description nc-dropdown-description">Chat with curl friends about your favorite curly topics</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="https://trendsetter.naturallycurly.com/" target="_blank">
# <span class="dropdown-title nc-dropdown-title">TRENDSETTER</span>
# <span class="dropdown-description nc-dropdown-description">Participate in product testing surveys discussions etc.</span>
# </a>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://shop.naturallycurly.com/" id="navbarDropdown5" target="_blank">
# SHOP
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.naturallycurly.com/contact" id="navbarDropdown6">
# <div class="purple-text">GET INVOLVED</div>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.essence.com" id="navbarDropdown7" target="_blank">
# <div class="purple-text">ESSENCE.COM</div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-2 col-sm-1 col-xl-2">
# <div class="navbar-right-container">
# <div class="navbar-items-container">
# <ul class="navbar-nav">
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbarDropdown8">
# <div class="child-right-container" id="shopping-cart-button"><i class="fas fa-shopping-cart"><mark class="number-cart-items"></mark></i> <span class="menu-text">My Cart</span></div>
# </a>
# <div aria-labelledby="navbarDropdown8" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="javascript:void(0)">
# <span class="dropdown-title nc-dropdown-title"><div id="shopping-cart-container"></div></span>
# <span class="dropdown-description nc-dropdown-description"></span>
# </a>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbarDropdown9">
# <div class="child-right-container" id="subscribe-button"><i class="far fa-envelope"></i> <span class="menu-text">SUBSCRIBE</span></div>
# </a>
# <div aria-labelledby="navbarDropdown9" class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="javascript:void(0)">
# <span class="dropdown-title nc-dropdown-title"><div id="subscribe-form-container"></div></span>
# <span class="dropdown-description nc-dropdown-description"></span>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="navbar-bottom-part">
# <ul class="subnavbar-nav">
# <li class="subnavbar-item">
# <a class="subnav-link" href="javascript:void(0)" id="navbarDropdown10">
# <div class="features-label">features:</div>
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/texture-tales" id="navbarDropdown11">
# TEXTURE TALES
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/leaders-in-curl" id="navbarDropdown12">
# LEADERS IN CURL
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/fresh-friday" id="navbarDropdown13">
# FRESH FRIDAY
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="https://www.naturallycurly.com/curlreading/texture-on-the-runway" id="navbarDropdown14">
# TEXTURE ON THE RUNWAY
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="javascript:void(0)" id="navbarDropdown15">
# <div id="search-form-container"></div>
# </a>
# </li>
# <li class="subnavbar-item">
# <a class="subnav-link" href="/login?redirectTo=https://curltalk.naturallycurly.com" id="navbarDropdown16-login" target="_blank">
# <div id="menu-login-container"></div>
# </a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="collapse navbar-collapse" id="navbarCollapser">
# <div class="navbar-sidebar-menu">
# <div class="navbar-items-container">
# <ul class="navbar-nav">
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/quiz" id="navbarDropdown0">
# TEXTURE
# </a>
# <div aria-labelledby="menu-texture" class="dropdown-menu nc-dropdown-menu sidebar-menu with-images">
# <div class="dropdown-menu-submenu nc-dropdown-menu-submenu with-images-submenu">
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <span class="dropdown-title nc-dropdown-title">WAVY (2a-2c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a loose “S” very easily straightened</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2a-720x864.jpg"/>
# </div>
# <span class="image-label">2a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2b-720x864.jpg"/>
# </div>
# <span class="image-label">2b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/waves">
# <div class="image-container">
# <img alt="2c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/2c-720x864.jpg"/>
# </div>
# <span class="image-label">2c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <span class="dropdown-title nc-dropdown-title">CURLY (3a-3c)</span>
# <span class="dropdown-description nc-dropdown-description">Forms a definite “S” shaped like a corkscrew</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3a-720x864.jpg"/>
# </div>
# <span class="image-label">3a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3b-720x864.jpg"/>
# </div>
# <span class="image-label">3b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/curls">
# <div class="image-container">
# <img alt="3c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/3c-720x864.jpg"/>
# </div>
# <span class="image-label">3c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <span class="dropdown-title nc-dropdown-title">COILY (4a-4c)</span>
# <span class="dropdown-description nc-dropdown-description">Very tight curl when stretched creates an “S”</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4a-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4a-720x864.jpg"/>
# </div>
# <span class="image-label">4a</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4b-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4b-720x864.jpg"/>
# </div>
# <span class="image-label">4b</span>
# </a>
# </div>
# <div class="num-childs-3">
# <a href="https://www.naturallycurly.com/curly-hair/coils">
# <div class="image-container">
# <img alt="4c-menu-image" class="" src="https://lndcdn.naturallycurly.com/hair-types/image/4c-720x864.jpg"/>
# </div>
# <span class="image-label">4c</span>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <span class="dropdown-title nc-dropdown-title">LOCS</span>
# <span class="dropdown-description nc-dropdown-description">Hair intentionally matted to form "ropes"</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/curly-hair/locs">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/ljbRc5dYtPNc1537231421.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# <span class="dropdown-item nc-dropdown-item with-images-submenu-item">
# <a href="https://www.naturallycurly.com/quiz">
# <span class="dropdown-title nc-dropdown-title">QUIZ</span>
# <span class="dropdown-description nc-dropdown-description">Take our quiz to learn your curl pattern</span>
# </a>
# <div class="dropdown-menu-sidebar nc-dropdown-menu-sidebar with-images-submenu-sidebar">
# <div class="num-childs-1">
# <a href="https://www.naturallycurly.com/quiz">
# <div class="image-container">
# <img alt="-menu-image" class="" src="https://diana-cdn.naturallycurly.com/general/Zosdxmktbe7i1537230313.jpg"/>
# </div>
# </a>
# </div>
# </div>
# </span>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/curlreading" id="navbarDropdown1">
# <div class="columns-menu">TOPICS</div>
# </a>
# <div class="dropdown-menu nc-dropdown-menu large-menu with-columns">
# <div class="nc-dropdown-menu-submenu">
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CONCERNS</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/dryness" id="dryness">Dryness</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/frizz-control" id="frizz">Frizz</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curl-definition" id="curl-definition">Curl Definition</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/detangling" id="detangling">Detangling</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-growth" id="hair-growth">Hair Growth</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/breakage" id="hair-breakage">Hair Breakage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/shrinkage" id="shrinkage">Shrinkage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hair-loss" id="hair-loss">Hair Loss</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/scalp-care" id="scalp-care">Scalp Care</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/heat-damage" id="heat-damage">Heat Damage</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/graying" id="graying">Graying</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/volume" id="volume">Volume</a></li>
# </ul>
# </div>
# </div>
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">CURL CARE</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/hair-color" id="hair-color">Hair Color</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/haircuts" id="haircuts">Haircuts</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/hairstyles" id="hairstyles">Hairstyles</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/transitioning" id="transitioning">Transitioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/straightening" id="straightening">Straightening</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/retexturizing" id="retexturizing">Retexturizing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/curly-girl-method" id="curly-girl-method">Curly Girl Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/l-o-c-method" id="loc-method">LOC Method</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/second-day-hair" id="2nd-day-hair">2nd Day Hair</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/cleansing" id="cleansing">Cleansing</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/conditioning" id="conditioning">Conditioning</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/for-kids" id="kids">Kids</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curly-hair/for-men" id="men">Men</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/salons" id="salon-finder">Salon Finder</a></li>
# </ul>
# </div>
# </div>
# <div class="nc-dropdown-menu-category">
# <span class="nc-dropdown-item headline-item dropdown-toggle nc-dropdown-toggle js-dropdown-toggle">LIFESTYLE</span>
# <div class="nc-dropdown-submenu">
# <ul class="nc-dropdown-list">
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/celebrities" id="celebrities">Celebrities</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/beauty" id="beauty">Beauty</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/self-care" id="self-care">Self-Care</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/culture" id="culture">Culture</a></li>
# <li class="nc-dropdown-list-item">
# <a class="nc-dropdown-subitem" href="https://www.naturallycurly.com/curlreading/business" id="business">Business</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.naturallycurly.com/videos" id="navbarDropdown2">
# VIDEOS
# </a>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.naturallycurly.com/curlreading/product" id="navbarDropdown3">
# PRODUCTS
# </a>
# ...
#                     " target="_blank">
# <span class="fa-stack fa-lg">
# <i class="fa fa-circle fa-stack-2x"></i>
# <i class="fab fa-youtube fa-stack-1x fa-inverse"></i>
# </span>
# </a>
# </div>
# <div>
# <a class="email" href="/cdn-cgi/l/email-protection#2c6f434242494f586c424d58595e4d4040554f595e4055024f4341" onclick="
#                                                                                                         return true;
#                     " target="_blank">
# <span class="fa-stack fa-lg">
# <i class="fa fa-circle fa-stack-2x"></i>
# <i class="far fa-envelope fa-stack-1x fa-inverse"></i>
# </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="text-center mt-4 copyright">
# © 2019 NaturallyCurly
# </div>
# </div>
# </footer>
# <div class="login-menu-templates">
# <div class="member-menu-container">
# <div class="user-navbar-menu">
# </div>
# <div class="user-logged-submenu">
# <div class="dropdown-menu nc-dropdown-menu">
# <div class="dropdown-menu-submenu nc-dropdown-submenu">
# <a class="dropdown-item nc-dropdown-item" href="/my-account">
# <span class="dropdown-title nc-dropdown-title">Edit My Account</span>
# </a>
# <a class="dropdown-item nc-dropdown-item profile-link" href="/user/view/username/">
# <span class="dropdown-title nc-dropdown-title">View My Public Profile</span>
# </a>
# <a class="dropdown-item nc-dropdown-item" href="/logout">
# <span class="dropdown-title nc-dropdown-title">Logout</span>
# </a>
# </div>
# </div>
# </div>
# </div> <div class="visitor-menu-container">
# <div class="user-navbar-menu">
# <div class="login-menu-btn" data-toggle="tooltip" title="Login">
# <i class="far fa-user-circle"></i><span class="login-text">Login</span>
# </div>
# </div>
# </div> </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="https://www.naturallycurly.com/js/app.js?id=0af96f538355dfe63c64"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/system-alerts/js/index.js?id=9a2b703c55c630ed81b6" type="text/javascript"></script>
# <script>
#         var csrfToken = "r8espbQAjIbeGDwID6nId4gRNQr3p6uaawtkpKQI";
#         var navbarPosition = 0;
#         var fixedMenu = null;
#         var navbarPlaceholder = null;
#         var windowWidth = $(window).width();
#         var isDesktop = false;
#
#         if (windowWidth > 990) {
#             isDesktop = true;
#         }
#
#         $(document).ready(function(){
#             initialConfig();
#             events();
#         });
#
#         function initialConfig(){
#             //We save the menu without the top ad
#             fixedMenu = $(".fixed-menu").first();
#
#             //We create the placeholder for avoid jumpiness when navbar is sticky
#             fixedMenu.wrap('<div class="nav-placeholder"></div>');
#             navbarPlaceholder = $(".nav-placeholder");
#             //We set to the placeholder the same height that the navbar
#             navbarPlaceholder.height(fixedMenu.outerHeight());
#             //We save the navbar position
#             navbarPosition = navbarPlaceholder.offset().top;
#         }
#
#         //(Only desktop function) this function hides the navbar extra content (featured menu and top ad)
#         function slideUpNavbarExtraContent(){
#             let featuredMenu = $(".navbar-bottom-part").first();
#             featuredMenu.slideUp();
#         }
#
#         //(Only desktop function) this function shows the navbar extra content (featured menu and top ad)
#         function slideDownNavbarExtraContent(){
#             let featuredMenu = $(".navbar-bottom-part").first();
#             featuredMenu.slideDown();
#         }
#
#         //Listener called when the Top ad is renderer
#         function navbarAdSlotRenderEndedListener(){
#             //We update the navbar position
#             navbarPosition = navbarPlaceholder.offset().top;
#         }
#
#         function events(){
#             $(window).on('scroll', function() {
#                 checkStickyNavbar();
#             });
#         }
#
#         function checkStickyNavbar(){
#             //Check the navbar stickiness
#             if (window.pageYOffset >= navbarPosition) {
#                 fixedMenu.addClass("sticky");
#             } else {
#                 fixedMenu.removeClass("sticky");
#             }
#
#             if(isDesktop){
#                 //400px after the navbar position we hide the extra-content
#                 if (window.pageYOffset >= navbarPosition + 400) {
#                     slideUpNavbarExtraContent();
#                 }
#                 else{
#                     slideDownNavbarExtraContent();
#                 }
#             }
#         }
#     </script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/js/index.js?id=0ba834f2665c88275e54" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/login/js/index.js?id=006265caa8a714a57d5e" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/search-bar/js/index.js?id=34d258b1afcca741dfc8" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/shopping-cart/js/index.js?id=a6912632f7d467c8376c" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/subscribe/js/index.js?id=975a2c737900651fdb1f" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/components/custom-navbar-items/features/js/index.js?id=f21ff9c1b82f82afe058" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/components/layout/navbar/components/navbar-container/js/index.js?id=8cb9b6c08927ac7dc7cf" type="text/javascript"></script>
# <script src="https://www.naturallycurly.com/assets/views/page-layouts/vanilla-forums-default-plain/js/index.js?id=e351f3eb460d64cfe2c4" type="text/javascript"></script>
# <script>
#         initDfpAdsFunctions['NC_T'] = function () {
#             googletag.cmd.push(function () {
#                 var mySizeMap_NC_T = googletag.sizeMapping()
#                                     .addSize([1024, 0], [[970, 250], [970, 90], [728, 90]])
#                                     .addSize([980, 0], [[728, 90]])
#                                     .addSize([640, 0], [468, 60])
#                                     .addSize([0, 0], [[320, 50], [300, 250], [300, 50]])
#                                     .build();
#
#                                     dfpAdSlots["NC_T"] = googletag.defineSlot('/21698916284/naturallycurly/topics', [[1, 1], [300, 250], [970, 250], [300, 600], [320, 50], [970, 90], [728, 90]], 'NC_T')
#                         .defineSizeMapping(mySizeMap_NC_T)
#                         .addService(googletag.pubads())
#                         .setTargeting("pos", "1")
#                         .setTargeting("tile", "1");
#
#                                     googletag.pubads().addEventListener('slotRenderEnded', function(event) {
#                         if (event.slot === dfpAdSlots["NC_T"]) {
#                             navbarAdSlotRenderEndedListener();
#                         }
#                     });
#
#             });
#         }
#     </script>
# <script>
#         initDfpAdsFunctions['NC_B'] = function () {
#             googletag.cmd.push(function () {
#                 var mySizeMap_NC_B = googletag.sizeMapping()
#                                     .addSize([1024, 0], [[970, 250], [970, 90], [728, 90]])
#                                     .addSize([980, 0], [[728, 90]])
#                                     .addSize([640, 0], [468, 60])
#                                     .addSize([0, 0], [[320, 50], [300, 50]])
#                                     .build();
#
#
#                     dfpAdSlots["NC_B"] = googletag.defineSlot('/21698916284/naturallycurly/topics', [[1, 1], [300, 250], [970, 250], [300, 600], [320, 50], [970, 90], [728, 90]], 'NC_B')
#                         .defineSizeMapping(mySizeMap_NC_B)
#                         .addService(googletag.pubads())
#                                                 .setTargeting("tile", "4");
#
#
#             });
#         }
#     </script>
# <script>
#             $.noConflict(true);
#         </script>
# <div aria-hidden="true" aria-labelledby="disableAdBlockerTitle" class="modal fade" id="disableAdBlockerContainer" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <div class="row">
# <img class="nc-img col-6" src="https://www.naturallycurly.com/img/naturallycurly.svg"/>
# <div class="col-6 d-flex">
# <h5 class="modal-title align-self-center" id="disableAdBlockerTitle"> team message</h5>
# </div>
# </div>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body text-center">
# Our website is made possible by displaying online advertisements to our visitors.<br/>
# Please consider supporting us by disabling your ad blocker on our website.
# <br/><br/>
# Thank you! :)
# </div>
# </div>
# </div>
# </div>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/blockadblock/3.2.1/blockadblock.min.js"></script>
# <script>
#     function requestAds() {
#         googletag.cmd.push(function() {
#
#             googletag.pubads().enableLazyLoad({
#                 fetchMarginPercent: 100,  // Fetch slots within 1 viewports.
#                 renderMarginPercent: 0,  // Render slots within 0 viewports.
#                 mobileScaling: 2.0  // Double the above values on mobile.
#             });
#
#             // Configure SRA
#             googletag.pubads().enableSingleRequest();
#
#             googletag.enableServices();
#
#             document.body.querySelectorAll('div[data-ad-slot]').forEach(function(element) {
#                 googletag.display(element.id);
#             })
#
#         });
#     }
#
#     // Function called if AdBlock is not detected
#     function adBlockNotDetected() {
#     }
#     // Function called if AdBlock is detected
#     function adBlockDetected() {
#         $("#disableAdBlockerContainer").modal('show');
#     }
#
#     function checkAdblock(){
#         // Recommended audit because AdBlock lock the file 'blockadblock.js'
#         // If the file is not called, the variable does not exist 'blockAdBlock'
#         // This means that AdBlock is present
#         if(typeof blockAdBlock === 'undefined') {
#             adBlockDetected();
#         } else {
#             blockAdBlock.onDetected(adBlockDetected);
# 	        blockAdBlock.onNotDetected(adBlockNotDetected);
#         }
#     }
#
#     $(document).ready(function(){
#         checkAdblock();
#     });
# </script>
# <script type="text/javascript">
# var iasDataHandler, __iasPET = __iasPET || {};
# __iasPET.queue = __iasPET.queue || [];
# __iasPET.pubId = '929481';
#
# var IASPET_TIMEOUT = 2000;
# var __iasPETTimeoutRequestAds = setTimeout(requestAds, IASPET_TIMEOUT);
#
# var iasDataHandler = function(adSlotData) {
# 	clearTimeout(__iasPETTimeoutRequestAds);
# 	__iasPET.setTargetingForGPT();
# 	requestAds();
# };
# </script>
# <script>
#
# //
# document.addEventListener('rendered_ads', function(e){
# 	// make the PET request
# 	googletag.cmd.push(function() {
# 		// read the currently defined GPT ad slots for sending to the PET endpoint
# 		// defined all GPT ad slots before calling PET
# 		var gptSlots = googletag.pubads().getSlots();
# 		//debugger;
# 		var iasPETSlots = [];
#
# 		for (var i = 0; i < gptSlots.length; i++) {
# 			var sizes = gptSlots[i].getSizes().map(function(size) {
# 				if (size.getWidth && size.getHeight)
# 					return [size.getWidth(), size.getHeight()];
# 				else
# 					return [1, 1];
# 			});
#
# 			iasPETSlots.push({
# 				adSlotId: gptSlots[i].getSlotElementId(),
# 				//size: can either be a single size (for example, [728, 90])
# 				// or an array of sizes (for example, [[728, 90], [970, 90]])
# 				size: sizes,
# 				adUnitPath: gptSlots[i].getAdUnitPath()
# 			});
# 		}
#
# 		// make the request to PET. if your page makes multiple ad requests to DFP
# 		// (for example, lazily loaded ads, infinite scrolling pages, etc.), make
# 		// a request to PET before every request to DFP
# 		__iasPET.queue.push({
# 			adSlots: iasPETSlots,
# 			dataHandler: iasDataHandler
# 		});
# 	});
#
# }, false);
# </script>
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "25511342" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=25511342&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script type="text/javascript">
#   var _qevents = _qevents || [];
#   (function(d, s, l, t) {
#     var elem = d.createElement(s); elem.src = (d.location.protocol == "https:" ? "https://secure" : "http://edge") + l;
#     elem.async = true; elem.type = t; var scpt = document.getElementsByTagName(s)[0];
#     scpt.parentNode.insertBefore(elem, scpt);
#   })(document, "script", ".quantserve.com/quant.js", "text/javascript");
# </script>
# <script type="text/javascript">
#   /* <![CDATA[ */
#     var google_conversion_id = 1067298743;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#   /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript"></script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1067298743/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <script>
#     var windowWidth = $(window).width();
#     var isDesktop = false;
#
#     if (windowWidth > 990) {
#         isDesktop = true;
#     }
#
#     function checkInitDfpFunctionAndRun(name){
#         if(initDfpAdsFunctions[name]){
#             initDfpAdsFunctions[name]();
#         }
#
#         delete initDfpAdsFunctions[name];
#     }
#
#     function showAdsArticleGrid(){
#         //We render the NC_TR ads depending the screensize
#         //extra large screens
#         if(windowWidth > 1400){
#             checkInitDfpFunctionAndRun("NC_TR_0");
#         }
#         //large screens
#         else if(windowWidth > 1200){
#             checkInitDfpFunctionAndRun("NC_TR_1");
#         }
#         //medium screens
#         else if(windowWidth > 992){
#             checkInitDfpFunctionAndRun("NC_TR_2");
#         }
#         //small and extra small screens
#         else{
#             checkInitDfpFunctionAndRun("NC_TR_3");
#         }
#
#         //we remove all the functions for avoid run any in the for
#         delete initDfpAdsFunctions["NC_TR_0"];
#         delete initDfpAdsFunctions["NC_TR_1"];
#         delete initDfpAdsFunctions["NC_TR_2"];
#         delete initDfpAdsFunctions["NC_TR_3"];
#     }
#
#     $(document).ready(function(){
#         checkInitDfpFunctionAndRun("NC_T");
#         if(!isDesktop){
#             checkInitDfpFunctionAndRun("NC_B");
#         }
#         checkInitDfpFunctionAndRun("NC_TR");
#         showAdsArticleGrid();
#         checkInitDfpFunctionAndRun("NC_BR");
#         if(isDesktop){
#             checkInitDfpFunctionAndRun("NC_B");
#         }
#
#         for(let functionName in initDfpAdsFunctions){
#             initDfpAdsFunctions[functionName]();
#         }
#
#         var event = document.createEvent('Event');
#         event.initEvent('rendered_ads', true, true);
#
#         document.dispatchEvent(event);
#     });
# </script>
# </body>
# </html>>

# %%
discussions_list = soup.find_all('ul', class_="DataList Discussions")
discussions_list
# Out:
# []
